# %%
# Importing dependencies

import json
import pandas as pd
import numpy as np

# importing regular expressions aka regex
import re

# importing sql alchamey to help port df to csv onto postgreSQL
from sqlalchemy import create_engine

from config import db_password

import time

# %%
# using an fstring to open a file directory

file_dir = '/D/GitHubRepos/Movies-ETL'
new_file_dir = './'

# pd.read_json method only works for data thats already clean
# JSON data has every field filled in every time it is returned, called “flat data"

# loading the messy json file with "with" and json.load() to save

with open(f'{new_file_dir}/wikipedia.movies.json', mode = 'r') as file:
    messy_wiki_movies = json.load(file)

# loaded movies json becomes a list of dictionaries

len(messy_wiki_movies)
# Out:
# 7311

# %%
# accessing dict records using slicing

messy_wiki_movies[:1]

# messy_wiki_movies[3500:3503]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/The_Adventures_of_Ford_Fairlane',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098987/',
#   'title': 'The Adventures of Ford Fairlane',
#   'Directed by': 'Renny Harlin',
#   'Produced by': ['Steve Perry', 'Joel Silver'],
#   'Screenplay by': ['David Arnott', 'James Cappe', 'Daniel Waters'],
#   'Story by': ['David Arnott', 'James Cappe'],
#   'Based on': ['Characters', 'by Rex Weiner'],
#   'Starring': ['Andrew Dice Clay',
#    'Wayne Newton',
#    'Priscilla Presley',
#    'Lauren Holly',
#    'Morris Day',
#    'Robert Englund',
#    "Ed O'Neill"],
#   'Narrated by': 'Andrew "Dice" Clay',
#   'Music by': ['Cliff Eidelman', 'Yello'],
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Michael Tronick',
#   'Productioncompany ': 'Silver Pictures',
#   'Distributed by': '20th Century Fox',
#   'Release date': ['July 11, 1990', '(', '1990-07-11', ')'],
#   'Running time': '102 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$21.4 million'}]

# %%
# importing kaggle to csv read

kaggle_metadata = pd.read_csv(f'{new_file_dir}movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{new_file_dir}ratings.csv')

# %%
ratings.head(5)

ratings.describe()

ratings.dtypes

# .sample(n='number') shows any random rows
# good practice to check the last few rows and a random sample of rows
# for consistent structure and explicit, unique id for each data point

ratings.sample(n=4)
# Out:
#           userId  movieId  rating   timestamp
# 13391982  139215    84152     2.5  1494381755
# 18773987  194955     2762     4.5  1359763420
# 17533939  181941      260     4.5  1492546745
# 3974786    41317     1097     4.0   981477439

# %%
kaggle_metadata.head(5).tail(4)

kaggle_metadata.dtypes

# ratings.sample(n=9)

# list(kaggle_metadata.coloumns())

kaggle_metadata.dtypes
kaggle_metadata.sample(n=3)
# Out:
#        adult                              belongs_to_collection     budget  \
# 25372  False                                                NaN          0
# 6783   False  {'id': 2344, 'name': 'The Matrix Collection', ...  150000000
# 16202  False                                                NaN          0
#
#                                                   genres homepage      id  \
# 25372                                                 []      NaN  268662
# 6783   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...      NaN     605
# 16202                   [{'id': 53, 'name': 'Thriller'}]      NaN   22135
#
#          imdb_id original_language          original_title  \
# 25372  tt0061668                en      Il fischio al naso
# 6783   tt0242653                en  The Matrix Revolutions
# 16202  tt1127221                en           Not Forgotten
#
#                                                 overview  ... release_date  \
# 25372  In this unusual offbeat black comedy directed ...  ...   1967-08-06
# 6783   The human city of Zion defends itself against ...  ...   2003-11-05
# 16202  Set in a Tex-Mex border town, Not Forgotten is...  ...   2009-09-11
#
#            revenue runtime                                   spoken_languages  \
# 25372          0.0     0.0                                                 []
# 6783   424988211.0   129.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 16202          0.0   100.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                      tagline  \
# 25372  Released                                          NaN
# 6783   Released  Everything that has a beginning has an end.
# 16202  Released                                          NaN
#
#                         title  video vote_average vote_count
# 25372      Il fischio al naso  False          0.0        0.0
# 6783   The Matrix Revolutions  False          6.4     3155.0
# 16202           Not Forgotten  False          5.3       23.0
#
# [3 rows x 24 columns]

# %%
# INSPECT and identify a problem , PLAN and decide whether to fix it, EXECUTE data repair

# deleting obviously bad data, removing superfluous columns (with one value or missing an overwhelming amount of data)
# removing duplicate rows, consolidating columns, and reshaping the data

# articulating the problems clearly, devising a plan to modify the data and fix the problem
# even if it might affect one data point, can it affect other rows

# Modifying data structure includes pivoting the values of one column into multiple columns, aggregating rows,
# and merging multiple data sets

# %%
# inspecting wiki data

wiki_movies_df = pd.DataFrame(messy_wiki_movies)

wiki_movies_df.head(5)
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# 2  Roger Spottiswoode               Daniel Melnick
# 3         Woody Allen              Robert Greenhut
# 4        John Cornell                 John Cornell
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                [James Foley, Robert Redlin]                          NaN
# 2                  [John Eskow, Richard Rush]                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  ... Predecessor  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...         NaN
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...  ...         NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...         NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...         NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...         NaN
#
#   Founders Area served Products Services Russian Hebrew Revenue  \
# 0      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 1      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 2      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 3      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 4      NaN         NaN      NaN      NaN     NaN    NaN     NaN
#
#   Operating income Polish
# 0              NaN    NaN
# 1              NaN    NaN
# 2              NaN    NaN
# 3              NaN    NaN
# 4              NaN    NaN
#
# [5 rows x 193 columns]

# %%
# converting the absurd amount of coloumn names into a list

wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Author',
#  'Publisher',
#  'Publication date',
#  'Media type',
#  'Pages',
#  'ISBN',
#  'OCLC',
#  'LC Class',
#  'Cover artist',
#  'Series',
#  'Set in',
#  'Adaptation by',
#  'Suggested by',
#  'Biographical data',
#  'Born',
#  'Died',
#  'Resting place',
#  'Occupation',
#  'Years active',
#  'Spouse(s)',
#  'Children',
#  'Parent(s)',
#  'Genres',
#  'Instruments',
#  'Labels',
#  'Website',
#  'Traditional',
#  'Mandarin',
#  'Type',
#  'Industry',
#  'Fate',
#  'Founded',
#  'Founder',
#  'Headquarters',
#  'Parent',
#  'Released',
#  'Recorded',
#  'Venue',
#  'Length',
#  'Label',
#  'Director',
#  'Producer',
#  'Area',
#  'Coordinates',
#  'Status',
#  'Opening date',
#  'Closing date',
#  'Replaced',
#  'Replaced by',
#  'Name',
#  'Attraction type',
#  'Music',
#  'Duration',
#  'Simplified Chinese',
#  'Traditional Chinese',
#  'Hanyu Pinyin',
#  'Literal meaning',
#  'Transcriptions',
#  'Bopomofo',
#  'Gwoyeu Romatzyh',
#  'Wade–Giles',
#  'IPA',
#  'Yale Romanization',
#  'Jyutping',
#  'Hokkien POJ',
#  'Animation by',
#  'Color process',
#  'Engine(s)',
#  'Genre(s)',
#  'Actor control',
#  'Production company',
#  'Release(s)',
#  'Format(s)',
#  'Simplified',
#  'Characters',
#  'Date premiered',
#  'Place premiered',
#  'Setting',
#  'Original language',
#  'Subject',
#  'Published',
#  'Dewey Decimal',
#  'Text',
#  'Illustrator',
#  'Original title',
#  'Published in English',
#  'French',
#  'Developed by',
#  'Ending theme',
#  'No. of seasons',
#  'Nationality',
#  'Portrayed by',
#  'Alias',
#  'Species',
#  'Gender',
#  'Family',
#  'Alma mater',
#  'Camera setup',
#  'Novel(s)',
#  'Comics',
#  'Film(s)',
#  'Screen story by',
#  'Hangul',
#  'Revised Romanization',
#  'McCune–Reischauer',
#  'Developer(s)',
#  'Publisher(s)',
#  'Designer(s)',
#  'Programmer(s)',
#  'Artist(s)',
#  'Writer(s)',
#  'Engine',
#  'Platform(s)',
#  'Release',
#  'Mode(s)',
#  'Original work',
#  'Television series',
#  'Japanese',
#  'Hepburn',
#  'Literally',
#  'Cantonese',
#  'Full name',
#  'Height',
#  'Seasons',
#  'Chinese',
#  'Other names',
#  'Relatives',
#  'Yiddish',
#  'Formerly',
#  'Key people',
#  'Total assets',
#  'Owner',
#  'Number of employees',
#  'Divisions',
#  'Subsidiaries',
#  'Arabic',
#  'Romanized',
#  'Predecessor',
#  'Founders',
#  'Area served',
#  'Products',
#  'Services',
#  'Russian',
#  'Hebrew',
#  'Revenue',
#  'Operating income',
#  'Polish']

# %%
# list comprehensions: rewind
# [expression for element in source_list]
# now we can [expression for element in source_list if filter_expression]

# filtering out wiki movies if their is a "director" or "directed by" key and a "imbd link" key

wiki_filterz = [movie for movie in messy_wiki_movies if ('Director' in movie or 'Directed by' in movie) and 'imdb_link' in movie]

len(wiki_filterz)

# # len(messy_wiki_movies)

wiki_director_imbd_filter_df = pd.DataFrame(wiki_filterz)

wiki_director_imbd_filter_df.head()


# down to 78 columns

wiki_director_imbd_filter_df.columns.tolist()

# adding to new df

wiki_filtered_movies_df = pd.DataFrame(wiki_director_imbd_filter_df)

wiki_filtered_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# 2  Roger Spottiswoode               Daniel Melnick
# 3         Woody Allen              Robert Greenhut
# 4        John Cornell                 John Cornell
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                [James Foley, Robert Redlin]                          NaN
# 2                  [John Eskow, Richard Rush]                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  ... Hepburn Literally  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...     NaN       NaN
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...  ...     NaN       NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...     NaN       NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...     NaN       NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...     NaN       NaN
#
#   Cantonese Chinese Yiddish Arabic Romanized Russian Hebrew Polish
# 0       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 1       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 2       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 3       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 4       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
#
# [5 rows x 78 columns]

# %%
# filtering out episodes since we only want movies 

wiki_episodes = [movie for movie in messy_wiki_movies
                if ('Director' in movie or 'Directed by' in movie)
                 and 'imdb_link' in movie
                 and 'No. of episodes' not in movie]

len(wiki_episodes)

wiki_movies_dfN = pd.DataFrame(wiki_episodes)

wiki_movies_dfN.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# 2  Roger Spottiswoode               Daniel Melnick
# 3         Woody Allen              Robert Greenhut
# 4        John Cornell                 John Cornell
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                [James Foley, Robert Redlin]                          NaN
# 2                  [John Eskow, Richard Rush]                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  ... Hepburn Literally  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...     NaN       NaN
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...  ...     NaN       NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...     NaN       NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...     NaN       NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...     NaN       NaN
#
#   Cantonese Chinese Yiddish Arabic Romanized Russian Hebrew Polish
# 0       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 1       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 2       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 3       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 4       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
#
# [5 rows x 75 columns]

# %%
# defining a function: Name, Parameters, Code block, Return value
# have to make sure dicts, lists data points dont get changed while calling on them inside a function
# thus, make copies using constructors like list(movies_list) and dict(movies_dict)

# enter lambda functions: anonymous functions that return a value without return call

# %%
# looking at the all the columns from the movies_df

wiki_movies_dfN.columns.tolist()

# alternate names in Arabic

wiki_movies_dfN[wiki_movies_dfN['Arabic'].notnull()]

wiki_movies_dfN[wiki_movies_dfN['Arabic'].notnull()]['url']

# sorting all the columns

sorted(wiki_movies_dfN.columns.tolist())
# Out:
# ['Adaptation by',
#  'Also known as',
#  'Animation by',
#  'Arabic',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cantonese',
#  'Chinese',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'French',
#  'Genre',
#  'Hangul',
#  'Hebrew',
#  'Hepburn',
#  'Japanese',
#  'Label',
#  'Language',
#  'Length',
#  'Literally',
#  'Mandarin',
#  'McCune–Reischauer',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Original title',
#  'Picture format',
#  'Polish',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
#  'Revised Romanization',
#  'Romanized',
#  'Running time',
#  'Russian',
#  'Screen story by',
#  'Screenplay by',
#  'Simplified',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Theme music composer',
#  'Traditional',
#  'Venue',
#  'Voices of',
#  'Written by',
#  'Yiddish',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
# trying to copy movies for a non-destrictive copy (as to not edit out original list/dict values)


# def clean_movie(movie):
#     movie_copy = dict(movie)
    
#     def clean_movie(movie):
#         movie = dict(movie)
        
#         return movie


# calling a functions and have 'yard' as a parameter

def clean_movies(yard):
# since the movies are dicts and needs a non-destructive copy

#     creating a non-destrcutive copy
    movie = dict(yard)

# dict holds empty alternate titles
    alt_titles = {}
    
#     looping through all the alt titles
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        
#       if key exists in the movie object
        if key in movie:
        
#         add key:value pair to alt_titles and remove from movie
            alt_titles[key] = movie[key]
            movie.pop(key)

#         adding alt_title to movie object
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles
            

    # consolidating similar columns names

    # changing every instance of 'Directed by' and adding it to the 'Director' key
    # changing every instance of an associated name/title and adding to one final consolidating column
    def change_column_name(old_name, new_name):
    
        if old_name in movie:
            
            movie[new_name] = movie.pop(old_name)
            
    change_column_name('Adaptation by', 'Writer(s)')
    change_column_name('Country of origin', 'Country')
    change_column_name('Directed by', 'Director')
    change_column_name('Distributed by', 'Distributor')
    change_column_name('Edited by', 'Editor(s)')
    change_column_name('Length', 'Running time')
    change_column_name('Original release', 'Release date')
    change_column_name('Music by', 'Composer(s)')
    change_column_name('Produced by', 'Producer(s)')
    change_column_name('Producer', 'Producer(s)')
    change_column_name('Productioncompanies ', 'Production company(s)')
    change_column_name('Productioncompany ', 'Production company(s)')
    change_column_name('Released', 'Release Date')
    change_column_name('Release Date', 'Release date')
    change_column_name('Screen story by', 'Writer(s)')
    change_column_name('Screenplay by', 'Writer(s)')
    change_column_name('Story by', 'Writer(s)')
    change_column_name('Theme music composer', 'Composer(s)')
    change_column_name('Written by', 'Writer(s)')
        
    return movie

clean_movies = [clean_movies(movie) for movie in wiki_episodes]

wiki_movies_df = pd.DataFrame(clean_movies)

sorted(wiki_movies_df.columns.tolist())

# for some reason, canvas has hebrew and mccunne-reischaur added this list
# Out:
# ['Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Created by',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Picture format',
#  'Preceded by',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Recorded',
#  'Release date',
#  'Running time',
#  'Starring',
#  'Suggested by',
#  'Venue',
#  'Voices of',
#  'Writer(s)',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
wiki_movies_df.head

wiki_movies_df.dtypes

wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Cinematography',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Composer(s)',
#  'Producer(s)',
#  'Production company(s)',
#  'Writer(s)',
#  'Genre',
#  'Original language(s)',
#  'Original network',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Created by',
#  'Preceded by',
#  'Suggested by',
#  'alt_titles',
#  'Recorded',
#  'Venue',
#  'Label',
#  'Animation by',
#  'Color process']

# %%
# regular expressions: regex, string of characters that define a search pattern
# just like MM/DD/YYY or (###)###-####

# using pandas str.extract() to extraxt IMDB ID from IMDB links since a typical IMDB link is...
# https://www.imdb.com/title/tt1234567/”, using extract in tt1234567 will get ID
# regex is "(tt\d{7})"

# ( ): parentheses marks looks for one group of text
# tt: matches two lowercase Ts
# \d{7} : match numerical digit 7 times

wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')

# 'r' denotes raw string value since Python also uses \ backslash operations for special characters
# as to distinguish this as a raw string in which to match using regex

wiki_movies_df['imdb_id']

print(len(wiki_movies_df))

# dropping duplicates within movies df in the subset IDs

wiki_movies_df.drop_duplicates(subset = 'imdb_id', inplace = True)

print(len(wiki_movies_df))

# dropped about 30 rows
# Out:
# 7076
# 7033

# %%
# # using list comprehension to display null values
# # [expression for element in source_list if filter_expression]

# # print(len(wiki_movies_df)*0.9)

[[column,wiki_movies_df[column].isnull().sum()] for column in wiki_movies_df.columns]

# # # half the column list has over 6000 null values

[column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df)*0.9]

# # selecting sum of null vales less 6.3k, which will be new df

selected_columns = [column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]

wiki_movies_df = wiki_movies_df[selected_columns]

wiki_movies_df
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 7071    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018
# 7072     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018
# 7073  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018
# 7074  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018
# 7075  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1     https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2     https://www.imdb.com/title/tt0099005/                      Air America
# 3     https://www.imdb.com/title/tt0099012/                            Alice
# 4     https://www.imdb.com/title/tt0099018/                  Almost an Angel
# ...                                     ...                              ...
# 7071  https://www.imdb.com/title/tt1255919/                  Holmes & Watson
# 7072  https://www.imdb.com/title/tt6266538/                             Vice
# 7073  https://www.imdb.com/title/tt4669788/              On the Basis of Sex
# 7074  https://www.imdb.com/title/tt7137380/                        Destroyer
# 7075  https://www.imdb.com/title/tt9495224/                     Bandersnatch
#
#                                                Based on  \
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7071  [Sherlock Holmes, and, Dr. Watson, by, Sir Art...
# 7072                                                NaN
# 7073                                                NaN
# 7074                                                NaN
# 7075                                                NaN
#
#                                                Starring  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]
# ...                                                 ...
# 7071  [Will Ferrell, John C. Reilly, Rebecca Hall, R...
# 7072  [Christian Bale, Amy Adams, Steve Carell, Sam ...
# 7073  [Felicity Jones, Armie Hammer, Justin Theroux,...
# 7074  [Nicole Kidman, Sebastian Stan, Toby Kebbell, ...
# 7075  [Fionn Whitehead, Will Poulter, Craig Parkinso...
#
#                      Cinematography  \
# 0                       Oliver Wood
# 1                      Mark Plummer
# 2                     Roger Deakins
# 3                    Carlo Di Palma
# 4                      Russell Boyd
# ...                             ...
# 7071                    Oliver Wood
# 7072                   Greig Fraser
# 7073                  Michael Grady
# 7074                 Julie Kirkwood
# 7075  [Aaron Morton, Jake Polonsky]
#
#                                            Release date  \
# 0                     [July 11, 1990, (, 1990-07-11, )]
# 1     [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...
# 2                   [August 10, 1990, (, 1990-08-10, )]
# 3                 [December 25, 1990, (, 1990-12-25, )]
# 4                                     December 19, 1990
# ...                                                 ...
# 7071  [December 25, 2018, (, 2018-12-25, ), (United ...
# 7072  [December 11, 2018, (, 2018-12-11, ), (, Samue...
# 7073  [November 8, 2018, (, 2018-11-08, ), (, AFI Fe...
# 7074  [August 31, 2018, (, 2018-08-31, ), (, Telluri...
# 7075               [28 December 2018, (, 2018-12-28, )]
#
#                                Running time         Country  ...       Budget  \
# 0                               102 minutes   United States  ...  $20 million
# 1                               114 minutes   United States  ...   $6 million
# 2                               113 minutes   United States  ...  $35 million
# 3                               106 minutes   United States  ...  $12 million
# 4                                95 minutes              US  ...  $25 million
# ...                                     ...             ...  ...          ...
# 7071                             90 minutes   United States  ...  $42 million
# 7072                            132 minutes   United States  ...  $60 million
# 7073                            120 minutes   United States  ...  $20 million
# 7074                            123 minutes   United States  ...   $9 million
# 7075  Variable; 90 minutes for default path  United Kingdom  ...          NaN
#
#             Box office            Director              Distributor  \
# 0        $21.4 million        Renny Harlin         20th Century Fox
# 1         $2.7 million         James Foley          Avenue Pictures
# 2          $57,718,089  Roger Spottiswoode         TriStar Pictures
# 3           $7,331,647         Woody Allen           Orion Pictures
# 4     $6,939,946 (USA)        John Cornell       Paramount Pictures
# ...                ...                 ...                      ...
# 7071     $41.9 million          Etan Cohen  Sony Pictures Releasing
# 7072     $76.1 million          Adam McKay         Mirror Releasing
# 7073     $38.4 million          Mimi Leder           Focus Features
# 7074      $5.5 million        Karyn Kusama         Mirror Releasing
# 7075               NaN         David Slade                  Netflix
#
#                            Editor(s)              Composer(s)  \
# 0                    Michael Tronick  [Cliff Eidelman, Yello]
# 1                    Howard E. Smith            Maurice Jarre
# 2     [John Bloom, Lois Freeman-Fox]            Charles Gross
# 3                     Susan E. Morse                      NaN
# 4                       David Stiven            Maurice Jarre
# ...                              ...                      ...
# 7071                  Dean Zimmerman        Mark Mothersbaugh
# 7072                     Hank Corwin         Nicholas Britell
# 7073                 Michelle Tesoro            Mychael Danna
# 7074                   Plummy Tucker         Theodore Shapiro
# 7075                     Tony Kearns           Brian Reitzell
#
#                                             Producer(s)  \
# 0                            [Steve Perry, Joel Silver]
# 1                           [Ric Kidney, Robert Redlin]
# 2                                        Daniel Melnick
# 3                                       Robert Greenhut
# 4                                          John Cornell
# ...                                                 ...
# 7071  [Will Ferrell, Adam McKay, Jimmy Miller, Clayt...
# 7072  [Brad Pitt, Dede Gardner, Jeremy Kleiner, Kevi...
# 7073                                     Robert W. Cort
# 7074             [Fred Berger, Phil Hay, Matt Manfredi]
# 7075                                     Russell McLean
#
#                                   Production company(s)  \
# 0                                       Silver Pictures
# 1                                       Avenue Pictures
# 2                 [Carolco Pictures, IndieProd Company]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7071  [Columbia Pictures, Gary Sanchez Productions, ...
# 7072  [Plan B Entertainment, Gary Sanchez Production...
# 7073  [Focus Features, [1], Participant Media, [1], ...
# 7074  [30West, Automatik Entertainment, Annapurna Pi...
# 7075                       [House of Tomorrow, Netflix]
#
#                          Writer(s)    imdb_id
# 0      [David Arnott, James Cappe]  tt0098987
# 1     [James Foley, Robert Redlin]  tt0098994
# 2       [John Eskow, Richard Rush]  tt0099005
# 3                      Woody Allen  tt0099012
# 4                       Paul Hogan  tt0099018
# ...                            ...        ...
# 7071                    Etan Cohen  tt1255919
# 7072                    Adam McKay  tt6266538
# 7073             Daniel Stiepleman  tt4669788
# 7074     [Phil Hay, Matt Manfredi]  tt7137380
# 7075               Charlie Brooker  tt9495224
#
# [7033 rows x 21 columns]

# %%
# converting data types into appropriate types

# such as box office should be numeric, budget should be numeric

wiki_movies_df.dtypes

# defined box office rows

# print(len(wiki_movies_df['Box office'].dropna()))

box_office_col = wiki_movies_df['Box office'].dropna()

len(box_office_col)

box_office_col

# since regex only works on strings, covert all of box office to strin
# using apply() to find which data points in box office arent strings

def is_not_a_string(x):
    return type(x) != str
# returns data type other than a string

box_office_col[box_office_col.map(is_not_a_string)]

# simplify this process using lambda, the anon caller

# lambda arguemnts: expression

# converting is_not_a_string function to a lambda expression

lambda x: type(x) != str

# within .map

box_office_col[box_office_col.map(lambda x: type(x) != str)]

# some data points multiple entries, such as "126 [US$1,531,489, (domestic)]"

# using join() concantenates into one string from string objects

box_office_col = box_office_col.apply(lambda x: ' '.join(x) if type(x) == list else x)

box_office_col
# Out:
# 0          $21.4 million
# 1           $2.7 million
# 2            $57,718,089
# 3             $7,331,647
# 4       $6,939,946 (USA)
#               ...
# 7070       $19.4 million
# 7071       $41.9 million
# 7072       $76.1 million
# 7073       $38.4 million
# 7074        $5.5 million
# Name: Box office, Length: 5485, dtype: object

# %%
# importing regex

import re

# simplyfing the box office column

form_one = r"\$\d+\.?\d*\s*[mb]illion"

# 'r' denotes raw string value since Python also uses \ backslash operations for special characters
# " expression begins
# \d signifies any digit 0-9
# + signifies one or more digits
# \. special character . for decimal place
# \d signifies any digit 0-9 
# * signfies 0 or more characters
# \s signifies whitespace (space)
# * signfies 0 or more characters
# [mb]illion signifies either million or billion
# expression signifies a matched case like "$837.32 million"

# count up how many box office values match first_form

(box_office_col.str.contains(form_one, flags=re.IGNORECASE).sum())

# flags=re.IGNORECASE ignore whether letter are upper or lowercase


# now without [mb]illion and comma separators such as $947,882,372


form_two = r"\$\d{1,3}(?:,\d{3})+"

# (?:,\d{3}) matches any group of 3 digits after a comma and its repetitons 
# with (?:...) telling not to extract any matches

(box_office_col.str.contains(form_two, flags=re.IGNORECASE).sum())

# figuring out whats left out from the matched cases

matches_form_one = box_office_col.str.contains(form_one, flags=re.IGNORECASE)
matches_form_two = box_office_col.str.contains(form_two, flags=re.IGNORECASE)

# # this will throw an error!
# box_office_col[(not matches_form_one) and (not matches_form_two)]

# using pythons element-wise logical operators: and &, not ~, or |
box_office_col[~matches_form_one & ~matches_form_two]
# Out:
# 34                         US$ 4,212,828
# 79                              $335.000
# 110                   $4.35-4.37 million
# 130                        US$ 4,803,039
# 600                           $5000 (US)
# 731                         $ 11,146,270
# 957                             $ 50,004
# 1070                          35,254,617
# 1147    $ 407,618 (U.S.) (sub-total) [1]
# 1446                        $ 11,829,959
# 1480                          £3 million
# 1611                            $520.000
# 1865                        ¥1.1 billion
# 2032                                 N/A
# 2091                                $309
# 2130               US$ 171.8 million [9]
# 2257                   US$ 3,395,581 [1]
# 2263            $ 1,223,034 ( domestic )
# 2347                            $282.175
# 2638            $ 104,883 (US sub-total)
# 2665         926,423 admissions (France)
# 2697      $ 1.7 million (US) (sub-total)
# 2823                            $414.000
# 2924                            $621.000
# 3088           $32 [2] –33.1 million [1]
# 3631                                 TBA
# 3859                  $38.9–40.3 million
# 3879            CN¥3.650 million (China)
# 4116                          £7,385,434
# 4123                            $161.000
# 4261                  $20.7–23.9 million
# 4306                              $20-30
# 4492                        $47.7 millon
# 4561             $45.2k (only in Turkey)
# 4662                USD$ 8.2 million [2]
# 5362                   $ 142 million [3]
# 5447                               £2.56
# 5784                            413 733$
# 6013                             Unknown
# 6145                  $17.5–18.4 million
# 6234                  $41.8–41.9 million
# 6369                               $111k
# 6370                                $588
# 6593                      less than $372
# 6829                    $ 41 million [3]
# 6843                             8 crore
# 6904                         $6.9 millon
# Name: Box office, dtype: object

# %%
# updated forms

form_one = r'\$\s*\d+\.?\d*\s*[mb]illi?on'
form_two = r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)'

def parse_dollars(s):
    # if s is not a string, return NaN
    if type(s) != str:
        return np.nan

    # if input is of the form $###.# million
    if re.match(r'\$\s*\d+\.?\d*\s*milli?on', s, flags=re.IGNORECASE):

        # remove dollar sign and " million"
        s = re.sub('\$|\s|[a-zA-Z]','', s)

        # convert to float and multiply by a million
        value = float(s) * 10**6

        # return value
        return value

    # if input is of the form $###.# billion
    elif re.match(r'\$\s*\d+\.?\d*\s*billi?on', s, flags=re.IGNORECASE):

        # remove dollar sign and " billion"
        s = re.sub('\$|\s|[a-zA-Z]','', s)

        # convert to float and multiply by a billion
        value = float(s) * 10**9

        # return value
        return value

    # if input is of the form $###,###,###
    elif re.match(r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)', s, flags=re.IGNORECASE):

        # remove dollar sign and commas
        s = re.sub('\$|,','', s)

        # convert to float
        value = float(s)

        # return value
        return value

    # otherwise, return NaN
    else:
        return np.nan

    
wiki_movies_df['box_office_col'] = box_office_col.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)

wiki_movies_df.drop('Box office', axis=1, inplace=True)

# %%
wiki_movies_df.columns.tolist()

wiki_movies_df
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 7071    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018
# 7072     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018
# 7073  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018
# 7074  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018
# 7075  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1     https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2     https://www.imdb.com/title/tt0099005/                      Air America
# 3     https://www.imdb.com/title/tt0099012/                            Alice
# 4     https://www.imdb.com/title/tt0099018/                  Almost an Angel
# ...                                     ...                              ...
# 7071  https://www.imdb.com/title/tt1255919/                  Holmes & Watson
# 7072  https://www.imdb.com/title/tt6266538/                             Vice
# 7073  https://www.imdb.com/title/tt4669788/              On the Basis of Sex
# 7074  https://www.imdb.com/title/tt7137380/                        Destroyer
# 7075  https://www.imdb.com/title/tt9495224/                     Bandersnatch
#
#                                                Based on  \
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7071  [Sherlock Holmes, and, Dr. Watson, by, Sir Art...
# 7072                                                NaN
# 7073                                                NaN
# 7074                                                NaN
# 7075                                                NaN
#
#                                                Starring  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]
# ...                                                 ...
# 7071  [Will Ferrell, John C. Reilly, Rebecca Hall, R...
# 7072  [Christian Bale, Amy Adams, Steve Carell, Sam ...
# 7073  [Felicity Jones, Armie Hammer, Justin Theroux,...
# 7074  [Nicole Kidman, Sebastian Stan, Toby Kebbell, ...
# 7075  [Fionn Whitehead, Will Poulter, Craig Parkinso...
#
#                      Cinematography  \
# 0                       Oliver Wood
# 1                      Mark Plummer
# 2                     Roger Deakins
# 3                    Carlo Di Palma
# 4                      Russell Boyd
# ...                             ...
# 7071                    Oliver Wood
# 7072                   Greig Fraser
# 7073                  Michael Grady
# 7074                 Julie Kirkwood
# 7075  [Aaron Morton, Jake Polonsky]
#
#                                            Release date  \
# 0                     [July 11, 1990, (, 1990-07-11, )]
# 1     [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...
# 2                   [August 10, 1990, (, 1990-08-10, )]
# 3                 [December 25, 1990, (, 1990-12-25, )]
# 4                                     December 19, 1990
# ...                                                 ...
# 7071  [December 25, 2018, (, 2018-12-25, ), (United ...
# 7072  [December 11, 2018, (, 2018-12-11, ), (, Samue...
# 7073  [November 8, 2018, (, 2018-11-08, ), (, AFI Fe...
# 7074  [August 31, 2018, (, 2018-08-31, ), (, Telluri...
# 7075               [28 December 2018, (, 2018-12-28, )]
#
#                                Running time         Country  ...       Budget  \
# 0                               102 minutes   United States  ...  $20 million
# 1                               114 minutes   United States  ...   $6 million
# 2                               113 minutes   United States  ...  $35 million
# 3                               106 minutes   United States  ...  $12 million
# 4                                95 minutes              US  ...  $25 million
# ...                                     ...             ...  ...          ...
# 7071                             90 minutes   United States  ...  $42 million
# 7072                            132 minutes   United States  ...  $60 million
# 7073                            120 minutes   United States  ...  $20 million
# 7074                            123 minutes   United States  ...   $9 million
# 7075  Variable; 90 minutes for default path  United Kingdom  ...          NaN
#
#                 Director              Distributor  \
# 0           Renny Harlin         20th Century Fox
# 1            James Foley          Avenue Pictures
# 2     Roger Spottiswoode         TriStar Pictures
# 3            Woody Allen           Orion Pictures
# 4           John Cornell       Paramount Pictures
# ...                  ...                      ...
# 7071          Etan Cohen  Sony Pictures Releasing
# 7072          Adam McKay         Mirror Releasing
# 7073          Mimi Leder           Focus Features
# 7074        Karyn Kusama         Mirror Releasing
# 7075         David Slade                  Netflix
#
#                            Editor(s)              Composer(s)  \
# 0                    Michael Tronick  [Cliff Eidelman, Yello]
# 1                    Howard E. Smith            Maurice Jarre
# 2     [John Bloom, Lois Freeman-Fox]            Charles Gross
# 3                     Susan E. Morse                      NaN
# 4                       David Stiven            Maurice Jarre
# ...                              ...                      ...
# 7071                  Dean Zimmerman        Mark Mothersbaugh
# 7072                     Hank Corwin         Nicholas Britell
# 7073                 Michelle Tesoro            Mychael Danna
# 7074                   Plummy Tucker         Theodore Shapiro
# 7075                     Tony Kearns           Brian Reitzell
#
#                                             Producer(s)  \
# 0                            [Steve Perry, Joel Silver]
# 1                           [Ric Kidney, Robert Redlin]
# 2                                        Daniel Melnick
# 3                                       Robert Greenhut
# 4                                          John Cornell
# ...                                                 ...
# 7071  [Will Ferrell, Adam McKay, Jimmy Miller, Clayt...
# 7072  [Brad Pitt, Dede Gardner, Jeremy Kleiner, Kevi...
# 7073                                     Robert W. Cort
# 7074             [Fred Berger, Phil Hay, Matt Manfredi]
# 7075                                     Russell McLean
#
#                                   Production company(s)  \
# 0                                       Silver Pictures
# 1                                       Avenue Pictures
# 2                 [Carolco Pictures, IndieProd Company]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7071  [Columbia Pictures, Gary Sanchez Productions, ...
# 7072  [Plan B Entertainment, Gary Sanchez Production...
# 7073  [Focus Features, [1], Participant Media, [1], ...
# 7074  [30West, Automatik Entertainment, Annapurna Pi...
# 7075                       [House of Tomorrow, Netflix]
#
#                          Writer(s)    imdb_id box_office_col
# 0      [David Arnott, James Cappe]  tt0098987     21400000.0
# 1     [James Foley, Robert Redlin]  tt0098994      2700000.0
# 2       [John Eskow, Richard Rush]  tt0099005     57718089.0
# 3                      Woody Allen  tt0099012      7331647.0
# 4                       Paul Hogan  tt0099018      6939946.0
# ...                            ...        ...            ...
# 7071                    Etan Cohen  tt1255919     41900000.0
# 7072                    Adam McKay  tt6266538     76100000.0
# 7073             Daniel Stiepleman  tt4669788     38400000.0
# 7074     [Phil Hay, Matt Manfredi]  tt7137380      5500000.0
# 7075               Charlie Brooker  tt9495224            NaN
#
# [7033 rows x 21 columns]

# %%
# fixing the budget column

budget = wiki_movies_df['Budget'].dropna()

# converting any list to strings

budget = budget.map(lambda x: ' '.join(x) if type(x) == list else x)

# creating formal regex expression

budget = budget.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)

# applying the form onto budget column

matches_form_one = budget.str.contains(form_one, flags=re.IGNORECASE)
matches_form_two = budget.str.contains(form_two, flags=re.IGNORECASE)
budget[~matches_form_one & ~matches_form_two]

# data points have citations in sqaure brackets, so removing them

budget = budget.str.replace(r'\[\d+\]\s*', '')
budget[~matches_form_one & ~matches_form_two]

# applying the parse_dollars function onto budget column

wiki_movies_df['budget'] = budget.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)

wiki_movies_df

wiki_movies_df.drop('Budget', axis=1, inplace=True)

# %%
wiki_movies_df
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 7071    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018
# 7072     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018
# 7073  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018
# 7074  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018
# 7075  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1     https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2     https://www.imdb.com/title/tt0099005/                      Air America
# 3     https://www.imdb.com/title/tt0099012/                            Alice
# 4     https://www.imdb.com/title/tt0099018/                  Almost an Angel
# ...                                     ...                              ...
# 7071  https://www.imdb.com/title/tt1255919/                  Holmes & Watson
# 7072  https://www.imdb.com/title/tt6266538/                             Vice
# 7073  https://www.imdb.com/title/tt4669788/              On the Basis of Sex
# 7074  https://www.imdb.com/title/tt7137380/                        Destroyer
# 7075  https://www.imdb.com/title/tt9495224/                     Bandersnatch
#
#                                                Based on  \
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7071  [Sherlock Holmes, and, Dr. Watson, by, Sir Art...
# 7072                                                NaN
# 7073                                                NaN
# 7074                                                NaN
# 7075                                                NaN
#
#                                                Starring  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]
# ...                                                 ...
# 7071  [Will Ferrell, John C. Reilly, Rebecca Hall, R...
# 7072  [Christian Bale, Amy Adams, Steve Carell, Sam ...
# 7073  [Felicity Jones, Armie Hammer, Justin Theroux,...
# 7074  [Nicole Kidman, Sebastian Stan, Toby Kebbell, ...
# 7075  [Fionn Whitehead, Will Poulter, Craig Parkinso...
#
#                      Cinematography  \
# 0                       Oliver Wood
# 1                      Mark Plummer
# 2                     Roger Deakins
# 3                    Carlo Di Palma
# 4                      Russell Boyd
# ...                             ...
# 7071                    Oliver Wood
# 7072                   Greig Fraser
# 7073                  Michael Grady
# 7074                 Julie Kirkwood
# 7075  [Aaron Morton, Jake Polonsky]
#
#                                            Release date  \
# 0                     [July 11, 1990, (, 1990-07-11, )]
# 1     [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...
# 2                   [August 10, 1990, (, 1990-08-10, )]
# 3                 [December 25, 1990, (, 1990-12-25, )]
# 4                                     December 19, 1990
# ...                                                 ...
# 7071  [December 25, 2018, (, 2018-12-25, ), (United ...
# 7072  [December 11, 2018, (, 2018-12-11, ), (, Samue...
# 7073  [November 8, 2018, (, 2018-11-08, ), (, AFI Fe...
# 7074  [August 31, 2018, (, 2018-08-31, ), (, Telluri...
# 7075               [28 December 2018, (, 2018-12-28, )]
#
#                                Running time         Country  ...  \
# 0                               102 minutes   United States  ...
# 1                               114 minutes   United States  ...
# 2                               113 minutes   United States  ...
# 3                               106 minutes   United States  ...
# 4                                95 minutes              US  ...
# ...                                     ...             ...  ...
# 7071                             90 minutes   United States  ...
# 7072                            132 minutes   United States  ...
# 7073                            120 minutes   United States  ...
# 7074                            123 minutes   United States  ...
# 7075  Variable; 90 minutes for default path  United Kingdom  ...
#
#                 Director              Distributor  \
# 0           Renny Harlin         20th Century Fox
# 1            James Foley          Avenue Pictures
# 2     Roger Spottiswoode         TriStar Pictures
# 3            Woody Allen           Orion Pictures
# 4           John Cornell       Paramount Pictures
# ...                  ...                      ...
# 7071          Etan Cohen  Sony Pictures Releasing
# 7072          Adam McKay         Mirror Releasing
# 7073          Mimi Leder           Focus Features
# 7074        Karyn Kusama         Mirror Releasing
# 7075         David Slade                  Netflix
#
#                            Editor(s)              Composer(s)  \
# 0                    Michael Tronick  [Cliff Eidelman, Yello]
# 1                    Howard E. Smith            Maurice Jarre
# 2     [John Bloom, Lois Freeman-Fox]            Charles Gross
# 3                     Susan E. Morse                      NaN
# 4                       David Stiven            Maurice Jarre
# ...                              ...                      ...
# 7071                  Dean Zimmerman        Mark Mothersbaugh
# 7072                     Hank Corwin         Nicholas Britell
# 7073                 Michelle Tesoro            Mychael Danna
# 7074                   Plummy Tucker         Theodore Shapiro
# 7075                     Tony Kearns           Brian Reitzell
#
#                                             Producer(s)  \
# 0                            [Steve Perry, Joel Silver]
# 1                           [Ric Kidney, Robert Redlin]
# 2                                        Daniel Melnick
# 3                                       Robert Greenhut
# 4                                          John Cornell
# ...                                                 ...
# 7071  [Will Ferrell, Adam McKay, Jimmy Miller, Clayt...
# 7072  [Brad Pitt, Dede Gardner, Jeremy Kleiner, Kevi...
# 7073                                     Robert W. Cort
# 7074             [Fred Berger, Phil Hay, Matt Manfredi]
# 7075                                     Russell McLean
#
#                                   Production company(s)  \
# 0                                       Silver Pictures
# 1                                       Avenue Pictures
# 2                 [Carolco Pictures, IndieProd Company]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7071  [Columbia Pictures, Gary Sanchez Productions, ...
# 7072  [Plan B Entertainment, Gary Sanchez Production...
# 7073  [Focus Features, [1], Participant Media, [1], ...
# 7074  [30West, Automatik Entertainment, Annapurna Pi...
# 7075                       [House of Tomorrow, Netflix]
#
#                          Writer(s)    imdb_id box_office_col      budget
# 0      [David Arnott, James Cappe]  tt0098987     21400000.0  20000000.0
# 1     [James Foley, Robert Redlin]  tt0098994      2700000.0   6000000.0
# 2       [John Eskow, Richard Rush]  tt0099005     57718089.0  35000000.0
# 3                      Woody Allen  tt0099012      7331647.0  12000000.0
# 4                       Paul Hogan  tt0099018      6939946.0  25000000.0
# ...                            ...        ...            ...         ...
# 7071                    Etan Cohen  tt1255919     41900000.0  42000000.0
# 7072                    Adam McKay  tt6266538     76100000.0  60000000.0
# 7073             Daniel Stiepleman  tt4669788     38400000.0  20000000.0
# 7074     [Phil Hay, Matt Manfredi]  tt7137380      5500000.0   9000000.0
# 7075               Charlie Brooker  tt9495224            NaN         NaN
#
# [7033 rows x 21 columns]

# %%
# parsing the release date column

release_date = wiki_movies_df['Release date'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)

# 4 types of date syntax, accounting for all using regex

date_form_one = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s[123]\d,\s\d{4}'
date_form_two = r'\d{4}.[01]\d.[123]\d'
date_form_three = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}'
date_form_four = r'\d{4}'

# extracting dates from release date column

release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})', flags=re.IGNORECASE)

# using pandas datetime function instead of another parsing function

wiki_movies_df['release_date'] = pd.to_datetime(release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})')[0], infer_datetime_format=True)

# %%
# parsing the runtime date column

# drops Na values and converts lists to strings
running_time = wiki_movies_df['Running time'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)

# summing ### minute matches
running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE).sum()

# what do the leftover cases that dont match look like?
running_time[running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE) != True]

# some have shorthand for minutes (min), other have compiled lists of minute in different movie editions
# marking only beginning of string, accept other abbreviations of minutes
running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE).sum()

# what do the leftover cases that dont match look like?
running_time[running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE) != True]

# in cases of "2273 1 h 43 min"
running_time_extract = running_time.str.extract(r'(\d+)\s*ho?u?r?s?\s*(\d*)|(\d+)\s*m')

# data type has to non-string, using to_numeric()
running_time_extract = running_time_extract.apply(lambda col: pd.to_numeric(col, errors='coerce')).fillna(0)

# converting the hours and minutes groups into minutes 
wiki_movies_df['running_time'] = running_time_extract.apply(lambda row: row[0]*60 + row[1] if row[2] == 0 else row[2], axis=1)


wiki_movies_df.drop('Running time', axis=1, inplace=True)

wiki_movies_df
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 7071    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018
# 7072     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018
# 7073  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018
# 7074  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018
# 7075  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1     https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2     https://www.imdb.com/title/tt0099005/                      Air America
# 3     https://www.imdb.com/title/tt0099012/                            Alice
# 4     https://www.imdb.com/title/tt0099018/                  Almost an Angel
# ...                                     ...                              ...
# 7071  https://www.imdb.com/title/tt1255919/                  Holmes & Watson
# 7072  https://www.imdb.com/title/tt6266538/                             Vice
# 7073  https://www.imdb.com/title/tt4669788/              On the Basis of Sex
# 7074  https://www.imdb.com/title/tt7137380/                        Destroyer
# 7075  https://www.imdb.com/title/tt9495224/                     Bandersnatch
#
#                                                Based on  \
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7071  [Sherlock Holmes, and, Dr. Watson, by, Sir Art...
# 7072                                                NaN
# 7073                                                NaN
# 7074                                                NaN
# 7075                                                NaN
#
#                                                Starring  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]
# ...                                                 ...
# 7071  [Will Ferrell, John C. Reilly, Rebecca Hall, R...
# 7072  [Christian Bale, Amy Adams, Steve Carell, Sam ...
# 7073  [Felicity Jones, Armie Hammer, Justin Theroux,...
# 7074  [Nicole Kidman, Sebastian Stan, Toby Kebbell, ...
# 7075  [Fionn Whitehead, Will Poulter, Craig Parkinso...
#
#                      Cinematography  \
# 0                       Oliver Wood
# 1                      Mark Plummer
# 2                     Roger Deakins
# 3                    Carlo Di Palma
# 4                      Russell Boyd
# ...                             ...
# 7071                    Oliver Wood
# 7072                   Greig Fraser
# 7073                  Michael Grady
# 7074                 Julie Kirkwood
# 7075  [Aaron Morton, Jake Polonsky]
#
#                                            Release date         Country  \
# 0                     [July 11, 1990, (, 1990-07-11, )]   United States
# 1     [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...   United States
# 2                   [August 10, 1990, (, 1990-08-10, )]   United States
# 3                 [December 25, 1990, (, 1990-12-25, )]   United States
# 4                                     December 19, 1990              US
# ...                                                 ...             ...
# 7071  [December 25, 2018, (, 2018-12-25, ), (United ...   United States
# 7072  [December 11, 2018, (, 2018-12-11, ), (, Samue...   United States
# 7073  [November 8, 2018, (, 2018-11-08, ), (, AFI Fe...   United States
# 7074  [August 31, 2018, (, 2018-08-31, ), (, Telluri...   United States
# 7075               [28 December 2018, (, 2018-12-28, )]  United Kingdom
#
#             Language  ...                       Editor(s)  \
# 0            English  ...                 Michael Tronick
# 1            English  ...                 Howard E. Smith
# 2     [English, Lao]  ...  [John Bloom, Lois Freeman-Fox]
# 3            English  ...                  Susan E. Morse
# 4            English  ...                    David Stiven
# ...              ...  ...                             ...
# 7071         English  ...                  Dean Zimmerman
# 7072         English  ...                     Hank Corwin
# 7073         English  ...                 Michelle Tesoro
# 7074         English  ...                   Plummy Tucker
# 7075         English  ...                     Tony Kearns
#
#                   Composer(s)  \
# 0     [Cliff Eidelman, Yello]
# 1               Maurice Jarre
# 2               Charles Gross
# 3                         NaN
# 4               Maurice Jarre
# ...                       ...
# 7071        Mark Mothersbaugh
# 7072         Nicholas Britell
# 7073            Mychael Danna
# 7074         Theodore Shapiro
# 7075           Brian Reitzell
#
#                                             Producer(s)  \
# 0                            [Steve Perry, Joel Silver]
# 1                           [Ric Kidney, Robert Redlin]
# 2                                        Daniel Melnick
# 3                                       Robert Greenhut
# 4                                          John Cornell
# ...                                                 ...
# 7071  [Will Ferrell, Adam McKay, Jimmy Miller, Clayt...
# 7072  [Brad Pitt, Dede Gardner, Jeremy Kleiner, Kevi...
# 7073                                     Robert W. Cort
# 7074             [Fred Berger, Phil Hay, Matt Manfredi]
# 7075                                     Russell McLean
#
#                                   Production company(s)  \
# 0                                       Silver Pictures
# 1                                       Avenue Pictures
# 2                 [Carolco Pictures, IndieProd Company]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7071  [Columbia Pictures, Gary Sanchez Productions, ...
# 7072  [Plan B Entertainment, Gary Sanchez Production...
# 7073  [Focus Features, [1], Participant Media, [1], ...
# 7074  [30West, Automatik Entertainment, Annapurna Pi...
# 7075                       [House of Tomorrow, Netflix]
#
#                          Writer(s)    imdb_id box_office_col      budget  \
# 0      [David Arnott, James Cappe]  tt0098987     21400000.0  20000000.0
# 1     [James Foley, Robert Redlin]  tt0098994      2700000.0   6000000.0
# 2       [John Eskow, Richard Rush]  tt0099005     57718089.0  35000000.0
# 3                      Woody Allen  tt0099012      7331647.0  12000000.0
# 4                       Paul Hogan  tt0099018      6939946.0  25000000.0
# ...                            ...        ...            ...         ...
# 7071                    Etan Cohen  tt1255919     41900000.0  42000000.0
# 7072                    Adam McKay  tt6266538     76100000.0  60000000.0
# 7073             Daniel Stiepleman  tt4669788     38400000.0  20000000.0
# 7074     [Phil Hay, Matt Manfredi]  tt7137380      5500000.0   9000000.0
# 7075               Charlie Brooker  tt9495224            NaN         NaN
#
#       release_date  running_time
# 0       1990-07-11         102.0
# 1       1990-05-17         114.0
# 2       1990-08-10         113.0
# 3       1990-12-25         106.0
# 4       1990-12-19          95.0
# ...            ...           ...
# 7071    2018-12-25          90.0
# 7072    2018-12-11         132.0
# 7073    2018-01-01         120.0
# 7074    2018-08-31         123.0
# 7075    2018-12-01          90.0
#
# [7033 rows x 22 columns]

# %%
# cleaning kaggle data

kaggle_metadata.dtypes

# cleaning adult and video data into boolean data types

kaggle_metadata['adult'].value_counts()

# adult booleans parsing and cleaning

kaggle_metadata[~kaggle_metadata['adult'].isin(['True','False'])]

# dropping corrupt and adult=True rows

kaggle_metadata = kaggle_metadata[kaggle_metadata['adult'] == 'False'].drop('adult',axis='columns')

# %%
# cleaning the video column
kaggle_metadata['video'].value_counts()

kaggle_metadata['video'] == 'True'

kaggle_metadata['video'] = kaggle_metadata['video'] == 'True'

# %%
# converting the numeric data types

kaggle_metadata['budget'] = kaggle_metadata['budget'].astype(int)
kaggle_metadata['id'] = pd.to_numeric(kaggle_metadata['id'], errors='raise')
kaggle_metadata['popularity'] = pd.to_numeric(kaggle_metadata['popularity'], errors='raise')

# %%
# converting release date to pandas to_datetime()

kaggle_metadata['release_date'] = pd.to_datetime(kaggle_metadata['release_date'])

kaggle_metadata
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45461                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 0      http://toystory.disney.com/toy-story     862  tt0114709
# 1                                       NaN    8844  tt0113497
# 2                                       NaN   15602  tt0113228
# 3                                       NaN   31357  tt0114885
# 4                                       NaN   11862  tt0113041
# ...                                     ...     ...        ...
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# 45465                                   NaN  461257  tt6980792
#
#       original_language               original_title  \
# 0                    en                    Toy Story
# 1                    en                      Jumanji
# 2                    en             Grumpier Old Men
# 3                    en            Waiting to Exhale
# 4                    en  Father of the Bride Part II
# ...                 ...                          ...
# 45461                fa                      رگ خواب
# 45462                tl          Siglo ng Pagluluwal
# 45463                en                     Betrayal
# 45464                en          Satana likuyushchiy
# 45465                en                     Queerama
#
#                                                 overview  popularity  ...  \
# 0      Led by Woody, Andy's toys live happily in his ...   21.946943  ...
# 1      When siblings Judy and Peter discover an encha...   17.015539  ...
# 2      A family wedding reignites the ancient feud be...   11.712900  ...
# 3      Cheated on, mistreated and stepped on, the wom...    3.859495  ...
# 4      Just when George Banks has recovered from his ...    8.387519  ...
# ...                                                  ...         ...  ...
# 45461        Rising and falling between a man and woman.    0.072051  ...
# 45462  An artist struggles to finish his work while a...    0.178241  ...
# 45463  When one of her hits goes wrong, a professiona...    0.903007  ...
# 45464  In a small town live two brothers, one a minis...    0.003503  ...
# 45465  50 years after decriminalisation of homosexual...    0.163015  ...
#
#       release_date      revenue runtime  \
# 0       1995-10-30  373554033.0    81.0
# 1       1995-12-15  262797249.0   104.0
# 2       1995-12-22          0.0   101.0
# 3       1995-12-22   81452156.0   127.0
# 4       1995-02-10   76578911.0   106.0
# ...            ...          ...     ...
# 45461          NaT          0.0    90.0
# 45462   2011-11-17          0.0   360.0
# 45463   2003-08-01          0.0    90.0
# 45464   1917-10-21          0.0    87.0
# 45465   2017-06-09          0.0    75.0
#
#                                         spoken_languages    status  \
# 0               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4               [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 45461             [{'iso_639_1': 'fa', 'name': 'فارسی'}]  Released
# 45462                  [{'iso_639_1': 'tl', 'name': ''}]  Released
# 45463           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 45464                                                 []  Released
# 45465           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45461         Rising and falling between a man and woman
# 45462                                                NaN
# 45463                             A deadly game of wits.
# 45464                                                NaN
# 45465                                                NaN
#
#                              title  video vote_average vote_count
# 0                        Toy Story  False          7.7     5415.0
# 1                          Jumanji  False          6.9     2413.0
# 2                 Grumpier Old Men  False          6.5       92.0
# 3                Waiting to Exhale  False          6.1       34.0
# 4      Father of the Bride Part II  False          5.7      173.0
# ...                            ...    ...          ...        ...
# 45461                       Subdue  False          4.0        1.0
# 45462          Century of Birthing  False          9.0        3.0
# 45463                     Betrayal  False          3.8        6.0
# 45464             Satan Triumphant  False          0.0        0.0
# 45465                     Queerama  False          0.0        0.0
#
# [45454 rows x 23 columns]

# %%
# looking at the ratings data

# using null_counts since there are so many rows
ratings.info(null_counts=True)

# converting timestamp data into pandas datetime unix

pd.to_datetime(ratings['timestamp'], unit='s')

# assinging to timestamp column
ratings['timestamp'] = pd.to_datetime(ratings['timestamp'], unit='s')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 4 columns):
#  #   Column     Non-Null Count     Dtype
# ---  ------     --------------     -----
#  0   userId     26024289 non-null  int64
#  1   movieId    26024289 non-null  int64
#  2   rating     26024289 non-null  float64
#  3   timestamp  26024289 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 794.2 MB

# %%
# actual ratings to check for errors, using a histogram, which shows how many times a data point
# shows up in data

ratings['rating'].plot(kind='hist')
ratings['rating'].describe()
# Out:
# count    2.602429e+07
# mean     3.528090e+00
# std      1.065443e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
# # combining kaggle, wiki data and finding redunant columns by assigning respective suffixes

movies_df = pd.merge(wiki_movies_df, kaggle_metadata, on='imdb_id', suffixes=['_wiki','_kaggle'])

movies_df.head()

movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title_wiki',
#  'Based on',
#  'Starring',
#  'Cinematography',
#  'Release date',
#  'Country',
#  'Language',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Composer(s)',
#  'Producer(s)',
#  'Production company(s)',
#  'Writer(s)',
#  'imdb_id',
#  'box_office_col',
#  'budget_wiki',
#  'release_date_wiki',
#  'running_time',
#  'belongs_to_collection',
#  'budget_kaggle',
#  'genres',
#  'homepage',
#  'id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date_kaggle',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title_kaggle',
#  'video',
#  'vote_average',
#  'vote_count']

# %%
# similar tables and what decision needs to be made

# Competing data:
# Wiki                     Movielens                Resolution
#--------------------------------------------------------------------------
# title_wiki               title_kaggle            dropping title_wiki
# running_time             runtime                 keep kaggle; fill 0 with wiki
# budget_wiki              budget_kaggle           keep kaggle; fill 0 with wiki
# box_office_col           revenue                 keep kaggle; fill 0 with wiki
# release_date_wiki        release_date_kaggle     drop wiki
# Language                 original_language       drop wiki
# Production company(s)    production_companies    drop wiki

# %%
# similar titles columns

movies_df[['title_wiki','title_kaggle']]

# looking at rows where titles might not match

movies_df[movies_df['title_wiki'] != movies_df['title_kaggle']][['title_wiki','title_kaggle']]

# kaggle seems more consistent with syntax and capitalization

# checking for missing or null data 
movies_df[(movies_df['title_kaggle'] == '') | (movies_df['title_kaggle'].isnull())]

# checks out, so drop title_wiki
# Out:
# Empty DataFrame
# Columns: [url, year, imdb_link, title_wiki, Based on, Starring, Cinematography, Release date, Country, Language, Director, Distributor, Editor(s), Composer(s), Producer(s), Production company(s), Writer(s), imdb_id, box_office_col, budget_wiki, release_date_wiki, running_time, belongs_to_collection, budget_kaggle, genres, homepage, id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date_kaggle, revenue, runtime, spoken_languages, status, tagline, title_kaggle, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 44 columns]

# %%
# runtime columns

# scatter plot to check for a straight line, which shows columns to be exactly same

# different values will scatter away from the central line

# comparing both running_time and runtime, while filling null values with 0

movies_df.fillna(0).plot(x='running_time', y='runtime', kind='scatter')

# thus keep Kaggle; fill in zeros with Wikipedia data

# %%
# budget columns

movies_df.fillna(0).plot.scatter(x='budget_wiki', y='budget_kaggle')

# Keep Kaggle; fill in zeros with Wikipedia data

# %%
# box office

movies_df.fillna(0).plot(x='box_office_col', y='revenue', kind='scatter')

# zoom-in since we are reaching billion

movies_df.fillna(0)[movies_df['box_office_col']<10**9].plot(x='box_office_col',y='revenue',kind='scatter')

# Keep Kaggle; fill in zeros with Wikipedia data

# %%
# release data

# since release data is datetime, use "scatter plot" by doing a simple line plot and adding "." style

movies_df[['release_date_wiki','release_date_kaggle']].plot(x='release_date_wiki', y='release_date_kaggle', style='.')

# outlier at 2006, looking at 1966 first

movies_df[(movies_df['release_date_wiki'] > '1996-01-01') & (movies_df['release_date_kaggle'] < '1965-01-01')]

# getting and dropping row

movies_df[(movies_df['release_date_wiki'] > '1996-01-01') & (movies_df['release_date_kaggle'] < '1965-01-01')].index

movies_df = movies_df.drop(movies_df[(movies_df['release_date_wiki'] > '1996-01-01') & (movies_df['release_date_kaggle'] < '1965-01-01')].index)

movies_df[movies_df['release_date_wiki'].isnull()]

# wiki has missing data, kaggle doesnt, so drop wiki
# Out:
#                                                     url  year  \
# 1008  https://en.wikipedia.org/wiki/Black_Scorpion_(...  1995
# 1061    https://en.wikipedia.org/wiki/Flirt_(1995_film)  1995
# 1121  https://en.wikipedia.org/wiki/Let_It_Be_Me_(19...  1995
# 1564  https://en.wikipedia.org/wiki/A_Brooklyn_State...  1997
# 1633      https://en.wikipedia.org/wiki/Highball_(film)  1997
# 1775        https://en.wikipedia.org/wiki/Velocity_Trap  1997
# 2386  https://en.wikipedia.org/wiki/The_Visit_(2000_...  2000
# 2786   https://en.wikipedia.org/wiki/Stevie_(2002_film)  2002
# 3174  https://en.wikipedia.org/wiki/Return_to_Sender...  2004
# 3651  https://en.wikipedia.org/wiki/Live_Free_or_Die...  2006
# 4967  https://en.wikipedia.org/wiki/For_the_Love_of_...  2012
#
#                                   imdb_link                title_wiki  \
# 1008  https://www.imdb.com/title/tt0112519/            Black Scorpion
# 1061  https://www.imdb.com/title/tt0113080/                     Flirt
# 1121  https://www.imdb.com/title/tt0113638/              Let It Be Me
# 1564  https://www.imdb.com/title/tt0118782/  A Brooklyn State of Mind
# 1633  https://www.imdb.com/title/tt0119291/                  Highball
# 1775  https://www.imdb.com/title/tt0120435/             Velocity Trap
# 2386  https://www.imdb.com/title/tt0199129/                 The Visit
# 2786  https://www.imdb.com/title/tt0334416/                    Stevie
# 3174  https://www.imdb.com/title/tt0396190/          Return to Sender
# 3651  https://www.imdb.com/title/tt0432318/          Live Free or Die
# 4967  https://www.imdb.com/title/tt1730294/     For the Love of Money
#
#      Based on                                           Starring  \
# 1008      NaN     [Joan Severance, Bruce Abbott, Garrett Morris]
# 1061      NaN            [Bill Sage, Dwight Ewell, Miho Nikaido]
# 1121      NaN                                                NaN
# 1564      NaN                                                NaN
# 1633      NaN  [Justine Bateman, Peter Bogdanovich, Chris Eig...
# 1775      NaN       [Olivier Gruner, Alicia Coppola, Ken Olandt]
# 2386      NaN  [Hill Harper, Billy Dee Williams, Obba Babatun...
# 2786      NaN                                                NaN
# 3174      NaN         [Aidan Quinn, Connie Nielsen, Mark Holton]
# 3651      NaN  [Aaron Stanford, Paul Schneider, Ebon Moss-Bac...
# 4967      NaN  [Yehuda Levi, Edward Furlong, James Caan, Jeff...
#
#                                   Cinematography Release date  \
# 1008                                Geoff George          NaN
# 1061                             Michael Spiller          NaN
# 1121                           Miroslav Ondrícek          NaN
# 1564                                  Ken Kelsch          NaN
# 1633                            Steven Bernstein          NaN
# 1775                          Philip D. Schwartz          NaN
# 2386                           John L. Demps Jr.          NaN
# 2786  [Dana Kupper, Gordon Quinn, Peter Gilbert]          NaN
# 3174                                         NaN          NaN
# 3651                                         NaN          NaN
# 4967                              Andrzej Sekuła          NaN
#
#                                    Country        Language  ...  \
# 1008                         United States             NaN  ...
# 1061  [United States, Germany, Japan, [1]]             NaN  ...
# 1121                                   NaN             NaN  ...
# 1564                                   NaN             NaN  ...
# 1633                         United States         English  ...
# 1775                         United States             NaN  ...
# 2386                                   NaN         English  ...
# 2786                         United States         English  ...
# 3174                    [Denmark, USA, UK]             NaN  ...
# 3651                         United States         English  ...
# 4967                         United States  English/Hebrew  ...
#
#      release_date_kaggle  revenue runtime  \
# 1008          1995-08-22      0.0    92.0
# 1061          1995-09-14      0.0    85.0
# 1121          1995-11-17      0.0    95.0
# 1564          1998-01-01      0.0    89.0
# 1633          1997-01-01      0.0   110.0
# 1775          1999-02-22      0.0    86.0
# 2386          2000-01-01      0.0   107.0
# 2786          2002-09-09  97000.0   140.0
# 3174          2004-09-17      0.0   109.0
# 3651          2006-03-11      0.0    89.0
# 4967          2012-06-08      0.0    93.0
#
#                                        spoken_languages    status  \
# 1008           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1061  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 1121                                                 []  Released
# 1564           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1633           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1775           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2386  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...   Rumored
# 2786                                                 []       NaN
# 3174           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3651           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4967  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                                 tagline  \
# 1008                         Justice has a nasty sting.
# 1061                                                NaN
# 1121                                                NaN
# 1564                                                NaN
# 1633                                                NaN
# 1775                        Crime at the Speed of Light
# 2386                                                NaN
# 2786                                                NaN
# 3174  How can you save someone, who won't save herself?
# 3651                                                NaN
# 4967     For the love of money is the root of all evil.
#
#                   title_kaggle  video  vote_average  vote_count
# 1008            Black Scorpion  False           6.1         7.0
# 1061                     Flirt  False           7.5         4.0
# 1121              Let It Be Me  False           8.0         2.0
# 1564  A Brooklyn State of Mind  False           5.0         1.0
# 1633                  Highball  False           4.5         4.0
# 1775             Velocity Trap  False           4.7         6.0
# 2386                 The Visit  False           0.0         0.0
# 2786                    Stevie  False           6.7        13.0
# 3174          Return to Sender  False           5.9        13.0
# 3651          Live Free or Die  False           5.5         8.0
# 4967     For the Love of Money  False           5.6         9.0
#
# [11 rows x 44 columns]

# %%
# languages 

movies_df['Language'].value_counts()

# coverting list to tuples as to use value_counts

movies_df['Language'].apply(lambda x: tuple(x) if type(x) == list else x).value_counts(dropna=False)

# kaggle language

movies_df['original_language'].value_counts(dropna=False)

# kaggle is more consistent with less languages, wiki has less consistent with more info on multiple languages

# so, drop wiki
# Out:
# en    5987
# fr      16
# es      10
# it       8
# de       6
# zh       4
# pt       4
# ja       4
# da       2
# hi       2
# he       1
# ko       1
# sv       1
# cn       1
# ab       1
# ar       1
# tr       1
# ru       1
# Name: original_language, dtype: int64

# %%
# production companies

movies_df[['Production company(s)','production_companies']]

# drop wiki
# Out:
#                                   Production company(s)  \
# 0                                       Silver Pictures
# 1                                       Avenue Pictures
# 2                 [Carolco Pictures, IndieProd Company]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6047                           [Fabula, Komplizen Film]
# 6048                           Ball & Chain Productions
# 6049          [Arte France Cinéma, Why Not Productions]
# 6050  [Film Science, Rough House Pictures, Syncopate...
# 6051         [HanWay Films, Little Punk, See-Saw Films]
#
#                                    production_companies
# 0     [{'name': 'Twentieth Century Fox Film Corporat...
# 1     [{'name': 'Avenue Pictures Productions', 'id':...
# 2     [{'name': 'IndieProd Company Productions', 'id...
# 3                [{'name': 'Orion Pictures', 'id': 41}]
# 4             [{'name': 'Paramount Pictures', 'id': 4}]
# ...                                                 ...
# 6047  [{'name': 'Komplizen Film', 'id': 1618}, {'nam...
# 6048  [{'name': 'Ball & Chain Productions', 'id': 74...
# 6049  [{'name': 'ARTE France Cinéma', 'id': 94}, {'n...
# 6050  [{'name': 'Film Science', 'id': 1976}, {'name'...
# 6051  [{'name': 'HanWay Films', 'id': 2395}, {'name'...
#
# [6051 rows x 2 columns]

# %%
# dropping wiki tables

movies_df.drop(columns=['title_wiki','release_date_wiki','Language','Production company(s)'], inplace=True)

movies_df
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 6047    https://en.wikipedia.org/wiki/A_Fantastic_Woman  2018
# 6048    https://en.wikipedia.org/wiki/Permission_(film)  2018
# 6049      https://en.wikipedia.org/wiki/Loveless_(film)  2018
# 6050   https://en.wikipedia.org/wiki/Gemini_(2017_film)  2018
# 6051  https://en.wikipedia.org/wiki/How_to_Talk_to_G...  2018
#
#                                   imdb_link  \
# 0     https://www.imdb.com/title/tt0098987/
# 1     https://www.imdb.com/title/tt0098994/
# 2     https://www.imdb.com/title/tt0099005/
# 3     https://www.imdb.com/title/tt0099012/
# 4     https://www.imdb.com/title/tt0099018/
# ...                                     ...
# 6047  https://www.imdb.com/title/tt5639354/
# 6048  https://www.imdb.com/title/tt5390066/
# 6049  https://www.imdb.com/title/tt6304162/
# 6050  https://www.imdb.com/title/tt5795086/
# 6051  https://www.imdb.com/title/tt3859310/
#
#                                                Based on  \
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6047                                                NaN
# 6048                                                NaN
# 6049                                                NaN
# 6050                                                NaN
# 6051  [", How to Talk to Girls at Parties, ", by, Ne...
#
#                                                Starring        Cinematography  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...           Oliver Wood
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...          Mark Plummer
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...         Roger Deakins
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...        Carlo Di Palma
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]          Russell Boyd
# ...                                                 ...                   ...
# 6047                    [Daniela Vega, Francisco Reyes]  Benjamín Echazarreta
# 6048  [Rebecca Hall, Dan Stevens, Morgan Spector, Fr...          Adam Bricker
# 6049  [Maryana Spivak, Aleksey Rozin, Matvey Novikov...      Mikhail Krichman
# 6050  [Lola Kirke, Zoë Kravitz, Greta Lee, Michelle ...           Andrew Reed
# 6051  [Elle Fanning, Alex Sharp, Nicole Kidman, Ruth...      Frank G. DeMarco
#
#                                            Release date  \
# 0                     [July 11, 1990, (, 1990-07-11, )]
# 1     [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...
# 2                   [August 10, 1990, (, 1990-08-10, )]
# 3                 [December 25, 1990, (, 1990-12-25, )]
# 4                                     December 19, 1990
# ...                                                 ...
# 6047  [12 February 2017, (, 2017-02-12, ), (, Berlin...
# 6048  [April 22, 2017, (, 2017-04-22, ), (, Tribeca ...
# 6049  [18 May 2017, (, 2017-05-18, ), (, Cannes, ), ...
# 6050  [March 12, 2017, (, 2017-03-12, ), (, SXSW, ),...
# 6051  [May 21, 2017, (, 2017-05-21, ), (, Cannes, ),...
#
#                                           Country               Director  \
# 0                                   United States           Renny Harlin
# 1                                   United States            James Foley
# 2                                   United States     Roger Spottiswoode
# 3                                   United States            Woody Allen
# 4                                              US           John Cornell
# ...                                           ...                    ...
# 6047  [Chile, Germany, Spain, United States, [2]]        Sebastián Lelio
# 6048                                United States            Brian Crano
# 6049      [Russia, France, Belgium, Germany, [3]]     Andrey Zvyagintsev
# 6050                                United States             Aaron Katz
# 6051              [United Kingdom, United States]  John Cameron Mitchell
#
#                                             Distributor  ...  \
# 0                                      20th Century Fox  ...
# 1                                       Avenue Pictures  ...
# 2                                      TriStar Pictures  ...
# 3                                        Orion Pictures  ...
# 4                                    Paramount Pictures  ...
# ...                                                 ...  ...
# 6047  [Participant Media (Chile), Piffl Medien (Germ...  ...
# 6048                            Good Deed Entertainment  ...
# 6049           [Sony Pictures Releasing, (Russia), [1]]  ...
# 6050                                               Neon  ...
# 6051                              [A24, StudioCanal UK]  ...
#
#      release_date_kaggle     revenue runtime  \
# 0             1990-07-11  20423389.0   104.0
# 1             1990-08-24         0.0   114.0
# 2             1990-08-10  33461269.0   112.0
# 3             1990-12-25         0.0   102.0
# 4             1990-12-21         0.0    95.0
# ...                  ...         ...     ...
# 6047          2017-04-06         0.0   104.0
# 6048          2017-04-22         0.0    96.0
# 6049          2017-06-01         0.0   128.0
# 6050          2017-03-12         0.0    92.0
# 6051          2017-12-27         0.0   102.0
#
#                                        spoken_languages           status  \
# 0              [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 1              [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 2     [{'iso_639_1': 'en', 'name': 'English'}, {'iso...         Released
# 3              [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 4              [{'iso_639_1': 'en', 'name': 'English'}]         Released
# ...                                                 ...              ...
# 6047           [{'iso_639_1': 'es', 'name': 'Español'}]         Released
# 6048           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 6049           [{'iso_639_1': 'ru', 'name': 'Pусский'}]         Released
# 6050           [{'iso_639_1': 'en', 'name': 'English'}]  Post Production
# 6051           [{'iso_639_1': 'en', 'name': 'English'}]         Released
#
#                                       tagline  \
# 0         Kojak. Columbo. Dirty Harry. Wimps.
# 1             All they risked was everything.
# 2     The few. The proud. The totally insane.
# 3                                         NaN
# 4                    Who does he think he is?
# ...                                       ...
# 6047                                      NaN
# 6048                                      NaN
# 6049                                      NaN
# 6050                                      NaN
# 6051        Some girls are out of this world.
#
#                          title_kaggle  video vote_average  vote_count
# 0     The Adventures of Ford Fairlane  False          6.2        72.0
# 1                After Dark, My Sweet  False          6.5        17.0
# 2                         Air America  False          5.3       146.0
# 3                               Alice  False          6.3        57.0
# 4                     Almost an Angel  False          5.6        23.0
# ...                               ...    ...          ...         ...
# 6047                A Fantastic Woman  False          7.2        13.0
# 6048                       Permission  False          0.0         1.0
# 6049                         Loveless  False          7.8        26.0
# 6050                           Gemini  False          0.0         0.0
# 6051  How to Talk to Girls at Parties  False          0.0        10.0
#
# [6051 rows x 40 columns]

# %%
# creating a function that fills missing values and drops redundant table

def fill_missing_kaggle_data(df, kaggle_column, wiki_column):
    
    df[kaggle_column] = df.apply(
        lambda row: row[wiki_column] if row[kaggle_column] == 0 else row[kaggle_column]
        , axis=1)
    df.drop(columns=wiki_column, inplace=True)
    
# run the columns within the function

fill_missing_kaggle_data(movies_df, 'runtime', 'running_time')

fill_missing_kaggle_data(movies_df, 'budget_kaggle', 'budget_wiki')

fill_missing_kaggle_data(movies_df, 'revenue', 'box_office_col')

movies_df
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 6047    https://en.wikipedia.org/wiki/A_Fantastic_Woman  2018
# 6048    https://en.wikipedia.org/wiki/Permission_(film)  2018
# 6049      https://en.wikipedia.org/wiki/Loveless_(film)  2018
# 6050   https://en.wikipedia.org/wiki/Gemini_(2017_film)  2018
# 6051  https://en.wikipedia.org/wiki/How_to_Talk_to_G...  2018
#
#                                   imdb_link  \
# 0     https://www.imdb.com/title/tt0098987/
# 1     https://www.imdb.com/title/tt0098994/
# 2     https://www.imdb.com/title/tt0099005/
# 3     https://www.imdb.com/title/tt0099012/
# 4     https://www.imdb.com/title/tt0099018/
# ...                                     ...
# 6047  https://www.imdb.com/title/tt5639354/
# 6048  https://www.imdb.com/title/tt5390066/
# 6049  https://www.imdb.com/title/tt6304162/
# 6050  https://www.imdb.com/title/tt5795086/
# 6051  https://www.imdb.com/title/tt3859310/
#
#                                                Based on  \
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6047                                                NaN
# 6048                                                NaN
# 6049                                                NaN
# 6050                                                NaN
# 6051  [", How to Talk to Girls at Parties, ", by, Ne...
#
#                                                Starring        Cinematography  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...           Oliver Wood
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...          Mark Plummer
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...         Roger Deakins
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...        Carlo Di Palma
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]          Russell Boyd
# ...                                                 ...                   ...
# 6047                    [Daniela Vega, Francisco Reyes]  Benjamín Echazarreta
# 6048  [Rebecca Hall, Dan Stevens, Morgan Spector, Fr...          Adam Bricker
# 6049  [Maryana Spivak, Aleksey Rozin, Matvey Novikov...      Mikhail Krichman
# 6050  [Lola Kirke, Zoë Kravitz, Greta Lee, Michelle ...           Andrew Reed
# 6051  [Elle Fanning, Alex Sharp, Nicole Kidman, Ruth...      Frank G. DeMarco
#
#                                            Release date  \
# 0                     [July 11, 1990, (, 1990-07-11, )]
# 1     [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...
# 2                   [August 10, 1990, (, 1990-08-10, )]
# 3                 [December 25, 1990, (, 1990-12-25, )]
# 4                                     December 19, 1990
# ...                                                 ...
# 6047  [12 February 2017, (, 2017-02-12, ), (, Berlin...
# 6048  [April 22, 2017, (, 2017-04-22, ), (, Tribeca ...
# 6049  [18 May 2017, (, 2017-05-18, ), (, Cannes, ), ...
# 6050  [March 12, 2017, (, 2017-03-12, ), (, SXSW, ),...
# 6051  [May 21, 2017, (, 2017-05-21, ), (, Cannes, ),...
#
#                                           Country               Director  \
# 0                                   United States           Renny Harlin
# 1                                   United States            James Foley
# 2                                   United States     Roger Spottiswoode
# 3                                   United States            Woody Allen
# 4                                              US           John Cornell
# ...                                           ...                    ...
# 6047  [Chile, Germany, Spain, United States, [2]]        Sebastián Lelio
# 6048                                United States            Brian Crano
# 6049      [Russia, France, Belgium, Germany, [3]]     Andrey Zvyagintsev
# 6050                                United States             Aaron Katz
# 6051              [United Kingdom, United States]  John Cameron Mitchell
#
#                                             Distributor  ...  \
# 0                                      20th Century Fox  ...
# 1                                       Avenue Pictures  ...
# 2                                      TriStar Pictures  ...
# 3                                        Orion Pictures  ...
# 4                                    Paramount Pictures  ...
# ...                                                 ...  ...
# 6047  [Participant Media (Chile), Piffl Medien (Germ...  ...
# 6048                            Good Deed Entertainment  ...
# 6049           [Sony Pictures Releasing, (Russia), [1]]  ...
# 6050                                               Neon  ...
# 6051                              [A24, StudioCanal UK]  ...
#
#      release_date_kaggle     revenue runtime  \
# 0             1990-07-11  20423389.0   104.0
# 1             1990-08-24   2700000.0   114.0
# 2             1990-08-10  33461269.0   112.0
# 3             1990-12-25   7331647.0   102.0
# 4             1990-12-21   6939946.0    95.0
# ...                  ...         ...     ...
# 6047          2017-04-06   3700000.0   104.0
# 6048          2017-04-22         NaN    96.0
# 6049          2017-06-01   4800000.0   128.0
# 6050          2017-03-12    200340.0    92.0
# 6051          2017-12-27    382053.0   102.0
#
#                                        spoken_languages           status  \
# 0              [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 1              [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 2     [{'iso_639_1': 'en', 'name': 'English'}, {'iso...         Released
# 3              [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 4              [{'iso_639_1': 'en', 'name': 'English'}]         Released
# ...                                                 ...              ...
# 6047           [{'iso_639_1': 'es', 'name': 'Español'}]         Released
# 6048           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 6049           [{'iso_639_1': 'ru', 'name': 'Pусский'}]         Released
# 6050           [{'iso_639_1': 'en', 'name': 'English'}]  Post Production
# 6051           [{'iso_639_1': 'en', 'name': 'English'}]         Released
#
#                                       tagline  \
# 0         Kojak. Columbo. Dirty Harry. Wimps.
# 1             All they risked was everything.
# 2     The few. The proud. The totally insane.
# 3                                         NaN
# 4                    Who does he think he is?
# ...                                       ...
# 6047                                      NaN
# 6048                                      NaN
# 6049                                      NaN
# 6050                                      NaN
# 6051        Some girls are out of this world.
#
#                          title_kaggle  video vote_average  vote_count
# 0     The Adventures of Ford Fairlane  False          6.2        72.0
# 1                After Dark, My Sweet  False          6.5        17.0
# 2                         Air America  False          5.3       146.0
# 3                               Alice  False          6.3        57.0
# 4                     Almost an Angel  False          5.6        23.0
# ...                               ...    ...          ...         ...
# 6047                A Fantastic Woman  False          7.2        13.0
# 6048                       Permission  False          0.0         1.0
# 6049                         Loveless  False          7.8        26.0
# 6050                           Gemini  False          0.0         0.0
# 6051  How to Talk to Girls at Parties  False          0.0        10.0
#
# [6051 rows x 37 columns]

# %%
# checking all columns that might have only 1 value_counts() value, if so, then drop

for col in movies_df.columns:
    
    lists_to_tuple = lambda x: tuple(x) if type(x) == list else x
    
    value_counts_check = movies_df[col].apply(lists_to_tuple).value_counts(dropna=False)
    
    num_values = len(value_counts_check)
    
    if num_values == 1:
    
        print(col)
        
        
# only video column shows up, so...

movies_df['video'].value_counts(dropna=False)

# list comprehension for the for loop above

# [print(col) for col in movies_df.columns if len(movies_df[col].apply(lambda x: tuple(x) if type(x) == list else x).value_counts(dropna=False))==1]

# dropping video column?

# movies_df.drop('video', axis=1, inplace=True)
# Out:
# video
# False    6051
# Name: video, dtype: int64

# %%
# sorting out columns from identification, quantitative and qualitative facts, business data, people

movies_df = movies_df.loc[:, [
    'imdb_id',
    'id',
    'title_kaggle',
    'original_title',
    'tagline',
    'belongs_to_collection',
    'url',
    'imdb_link',
    'runtime',
    'budget_kaggle',
    'revenue',
    'release_date_kaggle',
    'popularity',
    'vote_average',
    'vote_count',
    'genres',
    'original_language',
    'overview',
    'spoken_languages',
    'Country',
    'production_companies',
    'production_countries',
    'Distributor',
    'Producer(s)',
    'Director',
    'Starring',
    'Cinematography',
    'Editor(s)',
    'Writer(s)',
    'Composer(s)',
    'Based on']]

movies_df
# Out:
#         imdb_id      id                     title_kaggle  \
# 0     tt0098987    9548  The Adventures of Ford Fairlane
# 1     tt0098994   25501             After Dark, My Sweet
# 2     tt0099005   11856                      Air America
# 3     tt0099012    8217                            Alice
# 4     tt0099018   25943                  Almost an Angel
# ...         ...     ...                              ...
# 6047  tt5639354  429191                A Fantastic Woman
# 6048  tt5390066  390059                       Permission
# 6049  tt6304162  429174                         Loveless
# 6050  tt5795086  412302                           Gemini
# 6051  tt3859310  341689  How to Talk to Girls at Parties
#
#                        original_title  \
# 0     The Adventures of Ford Fairlane
# 1                After Dark, My Sweet
# 2                         Air America
# 3                               Alice
# 4                     Almost an Angel
# ...                               ...
# 6047             Una mujer fantástica
# 6048                       Permission
# 6049                         Нелюбовь
# 6050                           Gemini
# 6051  How to Talk to Girls at Parties
#
#                                       tagline belongs_to_collection  \
# 0         Kojak. Columbo. Dirty Harry. Wimps.                   NaN
# 1             All they risked was everything.                   NaN
# 2     The few. The proud. The totally insane.                   NaN
# 3                                         NaN                   NaN
# 4                    Who does he think he is?                   NaN
# ...                                       ...                   ...
# 6047                                      NaN                   NaN
# 6048                                      NaN                   NaN
# 6049                                      NaN                   NaN
# 6050                                      NaN                   NaN
# 6051        Some girls are out of this world.                   NaN
#
#                                                     url  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...
# 2      https://en.wikipedia.org/wiki/Air_America_(film)
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel
# ...                                                 ...
# 6047    https://en.wikipedia.org/wiki/A_Fantastic_Woman
# 6048    https://en.wikipedia.org/wiki/Permission_(film)
# 6049      https://en.wikipedia.org/wiki/Loveless_(film)
# 6050   https://en.wikipedia.org/wiki/Gemini_(2017_film)
# 6051  https://en.wikipedia.org/wiki/How_to_Talk_to_G...
#
#                                   imdb_link  runtime  budget_kaggle  ...  \
# 0     https://www.imdb.com/title/tt0098987/    104.0     49000000.0  ...
# 1     https://www.imdb.com/title/tt0098994/    114.0      6000000.0  ...
# 2     https://www.imdb.com/title/tt0099005/    112.0     35000000.0  ...
# 3     https://www.imdb.com/title/tt0099012/    102.0     12000000.0  ...
# 4     https://www.imdb.com/title/tt0099018/     95.0     25000000.0  ...
# ...                                     ...      ...            ...  ...
# 6047  https://www.imdb.com/title/tt5639354/    104.0            NaN  ...
# 6048  https://www.imdb.com/title/tt5390066/     96.0            NaN  ...
# 6049  https://www.imdb.com/title/tt6304162/    128.0            NaN  ...
# 6050  https://www.imdb.com/title/tt5795086/     92.0            NaN  ...
# 6051  https://www.imdb.com/title/tt3859310/    102.0            NaN  ...
#
#                                    production_countries  \
# 0     [{'iso_3166_1': 'US', 'name': 'United States o...
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...
# 3     [{'iso_3166_1': 'US', 'name': 'United States o...
# 4     [{'iso_3166_1': 'US', 'name': 'United States o...
# ...                                                 ...
# 6047  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...
# 6048  [{'iso_3166_1': 'US', 'name': 'United States o...
# 6049  [{'iso_3166_1': 'RU', 'name': 'Russia'}, {'iso...
# 6050  [{'iso_3166_1': 'US', 'name': 'United States o...
# 6051  [{'iso_3166_1': 'US', 'name': 'United States o...
#
#                                             Distributor  \
# 0                                      20th Century Fox
# 1                                       Avenue Pictures
# 2                                      TriStar Pictures
# 3                                        Orion Pictures
# 4                                    Paramount Pictures
# ...                                                 ...
# 6047  [Participant Media (Chile), Piffl Medien (Germ...
# 6048                            Good Deed Entertainment
# 6049           [Sony Pictures Releasing, (Russia), [1]]
# 6050                                               Neon
# 6051                              [A24, StudioCanal UK]
#
#                                             Producer(s)  \
# 0                            [Steve Perry, Joel Silver]
# 1                           [Ric Kidney, Robert Redlin]
# 2                                        Daniel Melnick
# 3                                       Robert Greenhut
# 4                                          John Cornell
# ...                                                 ...
# 6047              [Juan de Dios Larraín, Pablo Larraín]
# 6048                        [Brian Crano, Rebecca Hall]
# 6049  [Alexander Rodnyansky, Sergey Melkumov, Gleb F...
# 6050       [Mynette Louie, Sara Murphy, Adele Romanski]
# 6051  [Iain Canning, Howard Gertler, John Cameron Mi...
#
#                    Director  \
# 0              Renny Harlin
# 1               James Foley
# 2        Roger Spottiswoode
# 3               Woody Allen
# 4              John Cornell
# ...                     ...
# 6047        Sebastián Lelio
# 6048            Brian Crano
# 6049     Andrey Zvyagintsev
# 6050             Aaron Katz
# 6051  John Cameron Mitchell
#
#                                                Starring        Cinematography  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...           Oliver Wood
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...          Mark Plummer
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...         Roger Deakins
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...        Carlo Di Palma
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]          Russell Boyd
# ...                                                 ...                   ...
# 6047                    [Daniela Vega, Francisco Reyes]  Benjamín Echazarreta
# 6048  [Rebecca Hall, Dan Stevens, Morgan Spector, Fr...          Adam Bricker
# 6049  [Maryana Spivak, Aleksey Rozin, Matvey Novikov...      Mikhail Krichman
# 6050  [Lola Kirke, Zoë Kravitz, Greta Lee, Michelle ...           Andrew Reed
# 6051  [Elle Fanning, Alex Sharp, Nicole Kidman, Ruth...      Frank G. DeMarco
#
#                            Editor(s)  \
# 0                    Michael Tronick
# 1                    Howard E. Smith
# 2     [John Bloom, Lois Freeman-Fox]
# 3                     Susan E. Morse
# 4                       David Stiven
# ...                              ...
# 6047                 Soledad Salfate
# 6048                   Matt Friedman
# 6049                       Anna Mass
# 6050                      Aaron Katz
# 6051                  Brian A. Kates
#
#                                       Writer(s)  \
# 0                   [David Arnott, James Cappe]
# 1                  [James Foley, Robert Redlin]
# 2                    [John Eskow, Richard Rush]
# 3                                   Woody Allen
# 4                                    Paul Hogan
# ...                                         ...
# 6047            [Sebastián Lelio, Gonzalo Maza]
# 6048                                Brian Crano
# 6049           [Oleg Negin, Andrey Zvyagintsev]
# 6050                                 Aaron Katz
# 6051  [Philippa Goslett, John Cameron Mitchell]
#
#                                Composer(s)  \
# 0                  [Cliff Eidelman, Yello]
# 1                            Maurice Jarre
# 2                            Charles Gross
# 3                                      NaN
# 4                            Maurice Jarre
# ...                                    ...
# 6047                       Matthew Herbert
# 6048                                   NaN
# 6049  [Evgueni Galperine, Sacha Galperine]
# 6050                         Keegan DeWitt
# 6051           [Nico Muhly, Jamie Stewart]
#
#                                                Based on
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6047                                                NaN
# 6048                                                NaN
# 6049                                                NaN
# 6050                                                NaN
# 6051  [", How to Talk to Girls at Parties, ", by, Ne...
#
# [6051 rows x 31 columns]

# %%
# renaming the columns

movies_df.rename({'id':'kaggle_id',
                  'title_kaggle':'title',
                  'url':'wikipedia_url',
                  'budget_kaggle':'budget',
                  'release_date_kaggle':'release_date',
                  'Country':'country',
                  'Distributor':'distributor',
                  'Producer(s)':'producers',
                  'Director':'director',
                  'Starring':'starring',
                  'Cinematography':'cinematography',
                  'Editor(s)':'editors',
                  'Writer(s)':'writers',
                  'Composer(s)':'composers',
                  'Based on':'based_on'
                 }, axis='columns', inplace=True)

movies_df
# Out:
#         imdb_id  kaggle_id                            title  \
# 0     tt0098987       9548  The Adventures of Ford Fairlane
# 1     tt0098994      25501             After Dark, My Sweet
# 2     tt0099005      11856                      Air America
# 3     tt0099012       8217                            Alice
# 4     tt0099018      25943                  Almost an Angel
# ...         ...        ...                              ...
# 6047  tt5639354     429191                A Fantastic Woman
# 6048  tt5390066     390059                       Permission
# 6049  tt6304162     429174                         Loveless
# 6050  tt5795086     412302                           Gemini
# 6051  tt3859310     341689  How to Talk to Girls at Parties
#
#                        original_title  \
# 0     The Adventures of Ford Fairlane
# 1                After Dark, My Sweet
# 2                         Air America
# 3                               Alice
# 4                     Almost an Angel
# ...                               ...
# 6047             Una mujer fantástica
# 6048                       Permission
# 6049                         Нелюбовь
# 6050                           Gemini
# 6051  How to Talk to Girls at Parties
#
#                                       tagline belongs_to_collection  \
# 0         Kojak. Columbo. Dirty Harry. Wimps.                   NaN
# 1             All they risked was everything.                   NaN
# 2     The few. The proud. The totally insane.                   NaN
# 3                                         NaN                   NaN
# 4                    Who does he think he is?                   NaN
# ...                                       ...                   ...
# 6047                                      NaN                   NaN
# 6048                                      NaN                   NaN
# 6049                                      NaN                   NaN
# 6050                                      NaN                   NaN
# 6051        Some girls are out of this world.                   NaN
#
#                                           wikipedia_url  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...
# 2      https://en.wikipedia.org/wiki/Air_America_(film)
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel
# ...                                                 ...
# 6047    https://en.wikipedia.org/wiki/A_Fantastic_Woman
# 6048    https://en.wikipedia.org/wiki/Permission_(film)
# 6049      https://en.wikipedia.org/wiki/Loveless_(film)
# 6050   https://en.wikipedia.org/wiki/Gemini_(2017_film)
# 6051  https://en.wikipedia.org/wiki/How_to_Talk_to_G...
#
#                                   imdb_link  runtime      budget  ...  \
# 0     https://www.imdb.com/title/tt0098987/    104.0  49000000.0  ...
# 1     https://www.imdb.com/title/tt0098994/    114.0   6000000.0  ...
# 2     https://www.imdb.com/title/tt0099005/    112.0  35000000.0  ...
# 3     https://www.imdb.com/title/tt0099012/    102.0  12000000.0  ...
# 4     https://www.imdb.com/title/tt0099018/     95.0  25000000.0  ...
# ...                                     ...      ...         ...  ...
# 6047  https://www.imdb.com/title/tt5639354/    104.0         NaN  ...
# 6048  https://www.imdb.com/title/tt5390066/     96.0         NaN  ...
# 6049  https://www.imdb.com/title/tt6304162/    128.0         NaN  ...
# 6050  https://www.imdb.com/title/tt5795086/     92.0         NaN  ...
# 6051  https://www.imdb.com/title/tt3859310/    102.0         NaN  ...
#
#                                    production_countries  \
# 0     [{'iso_3166_1': 'US', 'name': 'United States o...
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...
# 3     [{'iso_3166_1': 'US', 'name': 'United States o...
# 4     [{'iso_3166_1': 'US', 'name': 'United States o...
# ...                                                 ...
# 6047  [{'iso_3166_1': 'FR', 'name': 'France'}, {'iso...
# 6048  [{'iso_3166_1': 'US', 'name': 'United States o...
# 6049  [{'iso_3166_1': 'RU', 'name': 'Russia'}, {'iso...
# 6050  [{'iso_3166_1': 'US', 'name': 'United States o...
# 6051  [{'iso_3166_1': 'US', 'name': 'United States o...
#
#                                             distributor  \
# 0                                      20th Century Fox
# 1                                       Avenue Pictures
# 2                                      TriStar Pictures
# 3                                        Orion Pictures
# 4                                    Paramount Pictures
# ...                                                 ...
# 6047  [Participant Media (Chile), Piffl Medien (Germ...
# 6048                            Good Deed Entertainment
# 6049           [Sony Pictures Releasing, (Russia), [1]]
# 6050                                               Neon
# 6051                              [A24, StudioCanal UK]
#
#                                               producers  \
# 0                            [Steve Perry, Joel Silver]
# 1                           [Ric Kidney, Robert Redlin]
# 2                                        Daniel Melnick
# 3                                       Robert Greenhut
# 4                                          John Cornell
# ...                                                 ...
# 6047              [Juan de Dios Larraín, Pablo Larraín]
# 6048                        [Brian Crano, Rebecca Hall]
# 6049  [Alexander Rodnyansky, Sergey Melkumov, Gleb F...
# 6050       [Mynette Louie, Sara Murphy, Adele Romanski]
# 6051  [Iain Canning, Howard Gertler, John Cameron Mi...
#
#                    director  \
# 0              Renny Harlin
# 1               James Foley
# 2        Roger Spottiswoode
# 3               Woody Allen
# 4              John Cornell
# ...                     ...
# 6047        Sebastián Lelio
# 6048            Brian Crano
# 6049     Andrey Zvyagintsev
# 6050             Aaron Katz
# 6051  John Cameron Mitchell
#
#                                                starring        cinematography  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...           Oliver Wood
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...          Mark Plummer
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...         Roger Deakins
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...        Carlo Di Palma
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]          Russell Boyd
# ...                                                 ...                   ...
# 6047                    [Daniela Vega, Francisco Reyes]  Benjamín Echazarreta
# 6048  [Rebecca Hall, Dan Stevens, Morgan Spector, Fr...          Adam Bricker
# 6049  [Maryana Spivak, Aleksey Rozin, Matvey Novikov...      Mikhail Krichman
# 6050  [Lola Kirke, Zoë Kravitz, Greta Lee, Michelle ...           Andrew Reed
# 6051  [Elle Fanning, Alex Sharp, Nicole Kidman, Ruth...      Frank G. DeMarco
#
#                              editors  \
# 0                    Michael Tronick
# 1                    Howard E. Smith
# 2     [John Bloom, Lois Freeman-Fox]
# 3                     Susan E. Morse
# 4                       David Stiven
# ...                              ...
# 6047                 Soledad Salfate
# 6048                   Matt Friedman
# 6049                       Anna Mass
# 6050                      Aaron Katz
# 6051                  Brian A. Kates
#
#                                         writers  \
# 0                   [David Arnott, James Cappe]
# 1                  [James Foley, Robert Redlin]
# 2                    [John Eskow, Richard Rush]
# 3                                   Woody Allen
# 4                                    Paul Hogan
# ...                                         ...
# 6047            [Sebastián Lelio, Gonzalo Maza]
# 6048                                Brian Crano
# 6049           [Oleg Negin, Andrey Zvyagintsev]
# 6050                                 Aaron Katz
# 6051  [Philippa Goslett, John Cameron Mitchell]
#
#                                  composers  \
# 0                  [Cliff Eidelman, Yello]
# 1                            Maurice Jarre
# 2                            Charles Gross
# 3                                      NaN
# 4                            Maurice Jarre
# ...                                    ...
# 6047                       Matthew Herbert
# 6048                                   NaN
# 6049  [Evgueni Galperine, Sacha Galperine]
# 6050                         Keegan DeWitt
# 6051           [Nico Muhly, Jamie Stewart]
#
#                                                based_on
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6047                                                NaN
# 6048                                                NaN
# 6049                                                NaN
# 6050                                                NaN
# 6051  [", How to Talk to Girls at Parties, ", by, Ne...
#
# [6051 rows x 31 columns]

# %%
# merging the ratings dataset, collapsing some row since data count is 26 million rows

# taking count for both movieid and rating with groupby

# renaming userid to count

# pivoting to make movieID as index, columns as rating values, and rows as count of rating value
rating_counts = ratings.groupby(['movieId','rating'], as_index=False).count() \
                .rename({'userId':'count'}, axis=1) \
                .pivot(index='movieId',columns='rating', values='count')

# prefix ratings before merging
rating_counts.columns = ['rating_' + str(col) for col in rating_counts.columns]

# left merging

movies_with_ratings_df = pd.merge(movies_df, rating_counts, left_on='kaggle_id', right_index=True, how='left')

# not every movie got a rating for each rating level, need to fill 
movies_with_ratings_df[rating_counts.columns] = movies_with_ratings_df[rating_counts.columns].fillna(0)

movies_with_ratings_df.columns.tolist()
# Out:
# ['imdb_id',
#  'kaggle_id',
#  'title',
#  'original_title',
#  'tagline',
#  'belongs_to_collection',
#  'wikipedia_url',
#  'imdb_link',
#  'runtime',
#  'budget',
#  'revenue',
#  'release_date',
#  'popularity',
#  'vote_average',
#  'vote_count',
#  'genres',
#  'original_language',
#  'overview',
#  'spoken_languages',
#  'country',
#  'production_companies',
#  'production_countries',
#  'distributor',
#  'producers',
#  'director',
#  'starring',
#  'cinematography',
#  'editors',
#  'writers',
#  'composers',
#  'based_on',
#  'rating_0.5',
#  'rating_1.0',
#  'rating_1.5',
#  'rating_2.0',
#  'rating_2.5',
#  'rating_3.0',
#  'rating_3.5',
#  'rating_4.0',
#  'rating_4.5',
#  'rating_5.0']

# %%
# creating database engine from postgreSQL to pandas

from config import db_password

# creating a db string based on "postgres://[user]:[password]@[location]:[port]/[database]"

db_string = f"postgres://postgres:{db_password}@localhost:5432/movie_data"

# starting the engine 

engine = create_engine(db_string)

# %%
# saving movies df to a sql table, specify name of table

movies_df.to_sql(name='movies', con=engine)

# %%
# chunksizing the rating data thats more than .5 gb

# creating a for loop to chunksize and keep record of sending data


rows_imported = 0

start_time = time.time()
# get start_time from time.time()

for data in pd.read_csv(f'./ratings.csv', chunksize=1000000):
    
#         printing the range of row being imported
    
    print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end = '')

    data.to_sql(name='rating', con=engine, if_exists='append')
    
#     increment number of rows imported by chunksize by crearting a variable and start with 0

    rows_imported += len(data)
    
#     print rows that finish importing
#     add elasped time to final print out
    print(f'Done. {time.time() - start_time} total seconds elapsed')
# Out:
# importing rows 0 to 1000000...Done. 93.42039036750793 total seconds elapsed
# importing rows 1000000 to 2000000...Done. 190.33909606933594 total seconds elapsed
# importing rows 2000000 to 3000000...Done. 282.7470211982727 total seconds elapsed
# importing rows 3000000 to 4000000...Done. 373.87034153938293 total seconds elapsed
# importing rows 4000000 to 5000000...Done. 464.52108335494995 total seconds elapsed
# importing rows 5000000 to 6000000...Done. 555.0763428211212 total seconds elapsed
# importing rows 6000000 to 7000000...Done. 645.821126461029 total seconds elapsed
# importing rows 7000000 to 8000000...Done. 736.3331544399261 total seconds elapsed
# importing rows 8000000 to 9000000...Done. 826.8496639728546 total seconds elapsed
# importing rows 9000000 to 10000000...Done. 921.548983335495 total seconds elapsed
# importing rows 10000000 to 11000000...Done. 1018.9452795982361 total seconds elapsed
# importing rows 11000000 to 12000000...Done. 1113.7482249736786 total seconds elapsed
# importing rows 12000000 to 13000000...Done. 1208.250628232956 total seconds elapsed
# importing rows 13000000 to 14000000...Done. 1294.7406911849976 total seconds elapsed
# importing rows 14000000 to 15000000...Done. 1385.3019137382507 total seconds elapsed
# importing rows 15000000 to 16000000...Done. 1471.7143502235413 total seconds elapsed
# importing rows 16000000 to 17000000...Done. 1557.2531924247742 total seconds elapsed
# importing rows 17000000 to 18000000...Done. 1644.03902053833 total seconds elapsed
# importing rows 18000000 to 19000000...Done. 1729.9005444049835 total seconds elapsed
# importing rows 19000000 to 20000000...Done. 1825.281138420105 total seconds elapsed
# importing rows 20000000 to 21000000...Done. 1920.9361317157745 total seconds elapsed
# importing rows 21000000 to 22000000...Done. 2017.9534182548523 total seconds elapsed
# importing rows 22000000 to 23000000...Done. 2112.337841272354 total seconds elapsed
# importing rows 23000000 to 24000000...Done. 2208.7259554862976 total seconds elapsed
# importing rows 24000000 to 25000000...Done. 2303.3209507465363 total seconds elapsed
# importing rows 25000000 to 26000000...Done. 2398.0741822719574 total seconds elapsed
# importing rows 26000000 to 26024289...Done. 2400.4327557086945 total seconds elapsed
